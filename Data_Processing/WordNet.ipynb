# %%
# !wget 'http://wordnet-rdf.princeton.edu/wn31.nt.gz'
# Out:
# --2022-02-08 00:44:22--  http://wordnet-rdf.princeton.edu/wn31.nt.gz
# Resolving wordnet-rdf.princeton.edu (wordnet-rdf.princeton.edu)... 128.112.144.14
# Connecting to wordnet-rdf.princeton.edu (wordnet-rdf.princeton.edu)|128.112.144.14|:80... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: /static/wordnet.nt.gz [following]
# --2022-02-08 00:44:22--  http://wordnet-rdf.princeton.edu/static/wordnet.nt.gz
# Reusing existing connection to wordnet-rdf.princeton.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 22253294 (21M) [application/octet-stream]
# Saving to: ‘wn31.nt.gz’
#
# wn31.nt.gz          100%[===================>]  21.22M  16.9MB/s    in 1.3s
#
# 2022-02-08 00:44:24 (16.9 MB/s) - ‘wn31.nt.gz’ saved [22253294/22253294]

# %%
# !gunzip wn31.nt.gz

# %%
# !python Fetch-WordNet.py wn31.nt
# Out:
# #### Removing duplicated lines in wn31.nt :... None
# done.
# #### WordNet 3.1... None
# done.
# #### processing prefixes... None
# done.
# #### Creating nodes and relationships... None
# #### Creating CSV files... None
# {':START_ID': '09977771-n', ':END_ID': '09977612-n', ':TYPE': 'wdo#antonym'}
# 09977771-n
# {':START_ID': '07516196-n', ':END_ID': '07517338-n', ':TYPE': 'wdo#antonym'}
# 07516196-n
# {':START_ID': '07517338-n', ':END_ID': '07516196-n', ':TYPE': 'wdo#antonym'}
# 07517338-n
# {':START_ID': '06820359-n', ':END_ID': '06820515-n', ':TYPE': 'wdo#antonym'}
# 06820359-n
# {':START_ID': '06197491-n', ':END_ID': '06197695-n', ':TYPE': 'wdo#antonym'}
# 06197491-n
# {':START_ID': '06197695-n', ':END_ID': '06197491-n', ':TYPE': 'wdo#antonym'}
# 06197695-n
# {':START_ID': '04939738-n', ':END_ID': '04940052-n', ':TYPE': 'wdo#antonym'}
# 04939738-n
# {':START_ID': '11572349-n', ':END_ID': '11572110-n', ':TYPE': 'wdo#antonym'}
# 11572349-n
# {':START_ID': '05635568-n', ':END_ID': '05637465-n', ':TYPE': 'wdo#antonym'}
# 05635568-n
# {':START_ID': '05637465-n', ':END_ID': '05635568-n', ':TYPE': 'wdo#antonym'}
# 05637465-n
# {':START_ID': '10262488-n', ':END_ID': '10291374-n', ':TYPE': 'wdo#antonym'}
# 10262488-n
# {':START_ID': '10291374-n', ':END_ID': '10262488-n', ':TYPE': 'wdo#antonym'}
# 10291374-n
# {':START_ID': '09977612-n', ':END_ID': '09977771-n', ':TYPE': 'wdo#antonym'}
# 09977612-n
# {':START_ID': '11572110-n', ':END_ID': '11572349-n', ':TYPE': 'wdo#antonym'}
# 11572110-n
# {':START_ID': '04940052-n', ':END_ID': '04939738-n', ':TYPE': 'wdo#antonym'}
# 04940052-n
# {':START_ID': '06820515-n', ':END_ID': '06820359-n', ':TYPE': 'wdo#antonym'}
# 06820515-n
# {':START_ID': '06164599-n', ':END_ID': '06164248-n', ':TYPE': 'wdo#antonym'}
# 06164599-n
# {':START_ID': '02462237-a', ':END_ID': '02462089-a', ':TYPE': 'wdo#antonym'}
# 02462237-a
# {':START_ID': '00140394-a', ':END_ID': '00140180-a', ':TYPE': 'wdo#antonym'}
# 00140394-a
# {':START_ID': '00252994-r', ':END_ID': '00253080-r', ':TYPE': 'wdo#antonym'}
# 00252994-r
# {':START_ID': '00140180-a', ':END_ID': '00140394-a', ':TYPE': 'wdo#antonym'}
# 00140180-a
# {':START_ID': '00253080-r', ':END_ID': '00252994-r', ':TYPE': 'wdo#antonym'}
# 00253080-r
# {':START_ID': '01670225-a', ':END_ID': '01670069-a', ':TYPE': 'wdo#antonym'}
# 01670225-a
# {':START_ID': '00002312-a', ':END_ID': '00002527-a', ':TYPE': 'wdo#antonym'}
# 00002312-a
# {':START_ID': '00515036-r', ':END_ID': '00515130-r', ':TYPE': 'wdo#antonym'}
# 00515036-r
# {':START_ID': '00002956-a', ':END_ID': '00003131-a', ':TYPE': 'wdo#antonym'}
# 00002956-a
# {':START_ID': '01452020-v', ':END_ID': '01451829-v', ':TYPE': 'wdo#antonym'}
# 01452020-v
# {':START_ID': '09203513-n', ':END_ID': '09203688-n', ':TYPE': 'wdo#antonym'}
# 09203513-n
# {':START_ID': '02610106-a', ':END_ID': '02614196-a', ':TYPE': 'wdo#antonym'}
# 02610106-a
# {':START_ID': '05207437-n', ':END_ID': '05214398-n', ':TYPE': 'wdo#antonym'}
# 05207437-n
# {':START_ID': '05624029-n', ':END_ID': '05652767-n', ':TYPE': 'wdo#antonym'}
# 05624029-n
# {':START_ID': '00001740-a', ':END_ID': '00002098-a', ':TYPE': 'wdo#antonym'}
# 00001740-a
# {':START_ID': '01600178-a', ':END_ID': '01598231-a', ':TYPE': 'wdo#antonym'}
# 01600178-a
# {':START_ID': '01603174-a', ':END_ID': '01602901-a', ':TYPE': 'wdo#antonym'}
# 01603174-a
# {':START_ID': '14525310-n', ':END_ID': '14524492-n', ':TYPE': 'wdo#antonym'}
# 14525310-n
# {':START_ID': '02432181-v', ':END_ID': '02431950-v', ':TYPE': 'wdo#antonym'}
# 02432181-v
# {':START_ID': '00174307-r', ':END_ID': '00174207-r', ':TYPE': 'wdo#antonym'}
# 00174307-r
# {':START_ID': '01669927-a', ':END_ID': '01669663-a', ':TYPE': 'wdo#antonym'}
# 01669927-a
# {':START_ID': '00080266-r', ':END_ID': '00080132-r', ':TYPE': 'wdo#antonym'}
# 00080266-r
# {':START_ID': '00080519-r', ':END_ID': '00080389-r', ':TYPE': 'wdo#antonym'}
# 00080519-r
# {':START_ID': '01110787-a', ':END_ID': '01110682-a', ':TYPE': 'wdo#antonym'}
# 01110787-a
# {':START_ID': '00004412-a', ':END_ID': '00004979-a', ':TYPE': 'wdo#antonym'}
# 00004412-a
# {':START_ID': '05076793-n', ':END_ID': '05077022-n', ':TYPE': 'wdo#antonym'}
# 05076793-n
# {':START_ID': '01236910-n', ':END_ID': '01236367-n', ':TYPE': 'wdo#antonym'}
# 01236910-n
# {':START_ID': '13984260-n', ':END_ID': '13980887-n', ':TYPE': 'wdo#antonym'}
# 13984260-n
# {':START_ID': '01853600-a', ':END_ID': '01852337-a', ':TYPE': 'wdo#antonym'}
# 01853600-a
# {':START_ID': '00005204-a', ':END_ID': '00006050-a', ':TYPE': 'wdo#antonym'}
# 00005204-a
# {':START_ID': '00904187-v', ':END_ID': '00844217-v', ':TYPE': 'wdo#antonym'}
# 00904187-v
# {':START_ID': '02771422-v', ':END_ID': '02773266-v', ':TYPE': 'wdo#antonym'}
# 02771422-v
# {':START_ID': '00008753-a', ':END_ID': '00008896-a', ':TYPE': 'wdo#antonym'}
# 00008753-a
# {':START_ID': '04948141-n', ':END_ID': '04949915-n', ':TYPE': 'wdo#antonym'}
# 04948141-n
# {':START_ID': '00006354-a', ':END_ID': '00007832-a', ':TYPE': 'wdo#antonym'}
# 00006354-a
# {':START_ID': '01198570-v', ':END_ID': '01159300-v', ':TYPE': 'wdo#antonym'}
# 01198570-v
# {':START_ID': '00009065-a', ':END_ID': '00009997-a', ':TYPE': 'wdo#antonym'}
# 00009065-a
# {':START_ID': '00011776-a', ':END_ID': '00013179-a', ':TYPE': 'wdo#antonym'}
# 00011776-a
# {':START_ID': '00199377-r', ':END_ID': '00199241-r', ':TYPE': 'wdo#antonym'}
# 00199377-r
# {':START_ID': '04769389-n', ':END_ID': '04767104-n', ':TYPE': 'wdo#antonym'}
# 04769389-n
# {':START_ID': '05122340-n', ':END_ID': '05124253-n', ':TYPE': 'wdo#antonym'}
# 05122340-n
# {':START_ID': '00013906-a', ':END_ID': '00016794-a', ':TYPE': 'wdo#antonym'}
# 00013906-a
# {':START_ID': '00017390-a', ':END_ID': '00017726-a', ':TYPE': 'wdo#antonym'}
# 00017390-a
# {':START_ID': '00317064-a', ':END_ID': '00316943-a', ':TYPE': 'wdo#antonym'}
# 00317064-a
# {':START_ID': '00318784-a', ':END_ID': '00318980-a', ':TYPE': 'wdo#antonym'}
# 00318784-a
# {':START_ID': '00318784-a', ':END_ID': '00319189-a', ':TYPE': 'wdo#antonym'}
# 00318784-a
# {':START_ID': '00321745-a', ':END_ID': '00320432-a', ':TYPE': 'wdo#antonym'}
# 00321745-a
# {':START_ID': '00323219-a', ':END_ID': '00321992-a', ':TYPE': 'wdo#antonym'}
# 00323219-a
# {':START_ID': '00439133-v', ':END_ID': '00440913-v', ':TYPE': 'wdo#antonym'}
# 00439133-v
# {':START_ID': '00440298-v', ':END_ID': '00439450-v', ':TYPE': 'wdo#antonym'}
# 00440298-v
# {':START_ID': '00331283-n', ':END_ID': '00331500-n', ':TYPE': 'wdo#antonym'}
# 00331283-n
# {':START_ID': '05067952-n', ':END_ID': '05068514-n', ':TYPE': 'wdo#antonym'}
# 05067952-n
# {':START_ID': '15300837-n', ':END_ID': '15301157-n', ':TYPE': 'wdo#antonym'}
# 15300837-n
# {':START_ID': '02298186-a', ':END_ID': '02298446-a', ':TYPE': 'wdo#antonym'}
# 02298186-a
# {':START_ID': '02298186-a', ':END_ID': '02297997-a', ':TYPE': 'wdo#antonym'}
# 02298186-a
# {':START_ID': '00688348-v', ':END_ID': '00687584-v', ':TYPE': 'wdo#antonym'}
# 00688348-v
# {':START_ID': '00799359-v', ':END_ID': '00799092-v', ':TYPE': 'wdo#antonym'}
# 00799359-v
# {':START_ID': '02240906-v', ':END_ID': '02242120-v', ':TYPE': 'wdo#antonym'}
# 02240906-v
# {':START_ID': '04799910-n', ':END_ID': '04801174-n', ':TYPE': 'wdo#antonym'}
# 04799910-n
# {':START_ID': '00017820-a', ':END_ID': '00018622-a', ':TYPE': 'wdo#antonym'}
# 00017820-a
# {':START_ID': '00055850-r', ':END_ID': '00056056-r', ':TYPE': 'wdo#antonym'}
# 00055850-r
# {':START_ID': '13955454-n', ':END_ID': '13960587-n', ':TYPE': 'wdo#antonym'}
# 13955454-n
# {':START_ID': '00076560-a', ':END_ID': '00076949-a', ':TYPE': 'wdo#antonym'}
# 00076560-a
# {':START_ID': '04726275-n', ':END_ID': '04730186-n', ':TYPE': 'wdo#antonym'}
# 04726275-n
# {':START_ID': '00019169-a', ':END_ID': '00019912-a', ':TYPE': 'wdo#antonym'}
# 00019169-a
# {':START_ID': '00040959-r', ':END_ID': '00062868-r', ':TYPE': 'wdo#antonym'}
# 00040959-r
# {':START_ID': '00063188-r', ':END_ID': '00062868-r', ':TYPE': 'wdo#antonym'}
# 00063188-r
# {':START_ID': '00020824-a', ':END_ID': '00021440-a', ':TYPE': 'wdo#antonym'}
# 00020824-a
# {':START_ID': '02258643-a', ':END_ID': '02258801-a', ':TYPE': 'wdo#antonym'}
# 02258643-a
# {':START_ID': '02259797-a', ':END_ID': '02259926-a', ':TYPE': 'wdo#antonym'}
# 02259797-a
# {':START_ID': '00555061-a', ':END_ID': '00556119-a', ':TYPE': 'wdo#antonym'}
# 00555061-a
# {':START_ID': '13427811-n', ':END_ID': '13428025-n', ':TYPE': 'wdo#antonym'}
# 13427811-n
# {':START_ID': '04810156-n', ':END_ID': '04811700-n', ':TYPE': 'wdo#antonym'}
# 04810156-n
# {':START_ID': '00021803-a', ':END_ID': '00023420-a', ':TYPE': 'wdo#antonym'}
# 00021803-a
# {':START_ID': '00205951-r', ':END_ID': '00206071-r', ':TYPE': 'wdo#antonym'}
# 00205951-r
# {':START_ID': '03053253-a', ':END_ID': '03053519-a', ':TYPE': 'wdo#antonym'}
# 03053253-a
# {':START_ID': '00024458-a', ':END_ID': '00024914-a', ':TYPE': 'wdo#antonym'}
# 00024458-a
# {':START_ID': '09782244-n', ':END_ID': '10292761-n', ':TYPE': 'wdo#antonym'}
# 09782244-n
# {':START_ID': '00366761-a', ':END_ID': '00366593-a', ':TYPE': 'wdo#antonym'}
# 00366761-a
# {':START_ID': '00367016-a', ':END_ID': '00366879-a', ':TYPE': 'wdo#antonym'}
# 00367016-a
# {':START_ID': '00387453-a', ':END_ID': '00367771-a', ':TYPE': 'wdo#antonym'}
# 00387453-a
# {':START_ID': '04967256-n', ':END_ID': '04966849-n', ':TYPE': 'wdo#antonym'}
# 04967256-n
# {':START_ID': '02707375-a', ':END_ID': '02706971-a', ':TYPE': 'wdo#antonym'}
# 02707375-a
# {':START_ID': '00026819-a', ':END_ID': '00027187-a', ':TYPE': 'wdo#antonym'}
# 00026819-a
# {':START_ID': '00025351-a', ':END_ID': '00025841-a', ':TYPE': 'wdo#antonym'}
# 00025351-a
# {':START_ID': '00025351-a', ':END_ID': '00026628-a', ':TYPE': 'wdo#antonym'}
# 00025351-a
# {':START_ID': '00265761-v', ':END_ID': '00265980-v', ':TYPE': 'wdo#antonym'}
# 00265761-v
# {':START_ID': '05046680-n', ':END_ID': '05046863-n', ':TYPE': 'wdo#antonym'}
# 05046680-n
# {':START_ID': '00027360-a', ':END_ID': '00028785-a', ':TYPE': 'wdo#antonym'}
# 00027360-a
# {':START_ID': '09783207-n', ':END_ID': '10680441-n', ':TYPE': 'wdo#antonym'}
# 09783207-n
# {':START_ID': '09783207-n', ':END_ID': '10680655-n', ':TYPE': 'wdo#antonym'}
# 09783207-n
# {':START_ID': '00029456-a', ':END_ID': '00031646-a', ':TYPE': 'wdo#antonym'}
# 00029456-a
# {':START_ID': '00905999-v', ':END_ID': '00908320-v', ':TYPE': 'wdo#antonym'}
# 00905999-v
# {':START_ID': '01196376-n', ':END_ID': '01191772-n', ':TYPE': 'wdo#antonym'}
# 01196376-n
# {':START_ID': '11559740-n', ':END_ID': '11559918-n', ':TYPE': 'wdo#antonym'}
# 11559740-n
# {':START_ID': '02600583-a', ':END_ID': '02600697-a', ':TYPE': 'wdo#antonym'}
# 02600583-a
# {':START_ID': '00031787-a', ':END_ID': '00031937-a', ':TYPE': 'wdo#antonym'}
# 00031787-a
# {':START_ID': '00002730-a', ':END_ID': '00002843-a', ':TYPE': 'wdo#antonym'}
# 00002730-a
# {':START_ID': '02372362-v', ':END_ID': '02731589-v', ':TYPE': 'wdo#antonym'}
# 02372362-v
# {':START_ID': '00799340-a', ':END_ID': '00799514-a', ':TYPE': 'wdo#antonym'}
# 00799340-a
# {':START_ID': '01670069-a', ':END_ID': '01670225-a', ':TYPE': 'wdo#antonym'}
# 01670069-a
# {':START_ID': '02382917-a', ':END_ID': '02383265-a', ':TYPE': 'wdo#antonym'}
# 02382917-a
# {':START_ID': '14030430-n', ':END_ID': '14033619-n', ':TYPE': 'wdo#antonym'}
# 14030430-n
# {':START_ID': '00191014-v', ':END_ID': '00191849-v', ':TYPE': 'wdo#antonym'}
# 00191014-v
# {':START_ID': '00237688-n', ':END_ID': '00234481-n', ':TYPE': 'wdo#antonym'}
# 00237688-n
# {':START_ID': '13447549-n', ':END_ID': '13517974-n', ':TYPE': 'wdo#antonym'}
# 13447549-n
# {':START_ID': '14747240-n', ':END_ID': '14748597-n', ':TYPE': 'wdo#antonym'}
# 14747240-n
# {':START_ID': '00032087-a', ':END_ID': '00033687-a', ':TYPE': 'wdo#antonym'}
# 00032087-a
# {':START_ID': '00034823-a', ':END_ID': '00035187-a', ':TYPE': 'wdo#antonym'}
# 00034823-a
# {':START_ID': '00035578-a', ':END_ID': '00036594-a', ':TYPE': 'wdo#antonym'}
# 00035578-a
# {':START_ID': '00037570-a', ':END_ID': '00037870-a', ':TYPE': 'wdo#antonym'}
# 00037570-a
# {':START_ID': '00038863-a', ':END_ID': '00039705-a', ':TYPE': 'wdo#antonym'}
# 00038863-a
# {':START_ID': '00040548-a', ':END_ID': '00040908-a', ':TYPE': 'wdo#antonym'}
# 00040548-a
# {':START_ID': '00041583-a', ':END_ID': '00041273-a', ':TYPE': 'wdo#antonym'}
# 00041583-a
# {':START_ID': '00041840-a', ':END_ID': '00042063-a', ':TYPE': 'wdo#antonym'}
# 00041840-a
# {':START_ID': '00042258-a', ':END_ID': '00042449-a', ':TYPE': 'wdo#antonym'}
# 00042258-a
# {':START_ID': '00042677-a', ':END_ID': '00043345-a', ':TYPE': 'wdo#antonym'}
# 00042677-a
# {':START_ID': '00043630-a', ':END_ID': '00043834-a', ':TYPE': 'wdo#antonym'}
# 00043630-a
# {':START_ID': '13382123-n', ':END_ID': '13382506-n', ':TYPE': 'wdo#antonym'}
# 13382123-n
# {':START_ID': '13825370-n', ':END_ID': '13825643-n', ':TYPE': 'wdo#antonym'}
# 13825370-n
# {':START_ID': '00079883-r', ':END_ID': '00080014-r', ':TYPE': 'wdo#antonym'}
# 00079883-r
# {':START_ID': '04642461-n', ':END_ID': '04642988-n', ':TYPE': 'wdo#antonym'}
# 04642461-n
# {':START_ID': '14030430-n', ':END_ID': '14033619-n', ':TYPE': 'wdo#antonym'}
# 14030430-n
# {':START_ID': '00408356-n', ':END_ID': '01064507-n', ':TYPE': 'wdo#antonym'}
# 00408356-n
# {':START_ID': '14030430-n', ':END_ID': '14033619-n', ':TYPE': 'wdo#antonym'}
# 14030430-n
# {':START_ID': '00043985-a', ':END_ID': '00044573-a', ':TYPE': 'wdo#antonym'}
# 00043985-a
# {':START_ID': '00758690-n', ':END_ID': '00758836-n', ':TYPE': 'wdo#antonym'}
# 00758690-n
# {':START_ID': '00044980-a', ':END_ID': '00045343-a', ':TYPE': 'wdo#antonym'}
# 00044980-a
# {':START_ID': '01817105-a', ':END_ID': '01817190-a', ':TYPE': 'wdo#antonym'}
# 01817105-a
# {':START_ID': '00141793-r', ':END_ID': '00141918-r', ':TYPE': 'wdo#antonym'}
# 00141793-r
# {':START_ID': '04712884-n', ':END_ID': '04713298-n', ':TYPE': 'wdo#antonym'}
# 04712884-n
# {':START_ID': '00680581-a', ':END_ID': '00679823-a', ':TYPE': 'wdo#antonym'}
# 00680581-a
# {':START_ID': '00681144-a', ':END_ID': '00680812-a', ':TYPE': 'wdo#antonym'}
# 00681144-a
# {':START_ID': '04666447-n', ':END_ID': '04667437-n', ':TYPE': 'wdo#antonym'}
# 04666447-n
# {':START_ID': '01030878-a', ':END_ID': '01032659-a', ':TYPE': 'wdo#antonym'}
# 01030878-a
# {':START_ID': '00046329-a', ':END_ID': '00046893-a', ':TYPE': 'wdo#antonym'}
# 00046329-a
# {':START_ID': '00002527-a', ':END_ID': '00002312-a', ':TYPE': 'wdo#antonym'}
# 00002527-a
# {':START_ID': '00515130-r', ':END_ID': '00515036-r', ':TYPE': 'wdo#antonym'}
# 00515130-r
# {':START_ID': '00182551-v', ':END_ID': '00179456-v', ':TYPE': 'wdo#antonym'}
# 00182551-v
# {':START_ID': '00642490-v', ':END_ID': '00642914-v', ':TYPE': 'wdo#antonym'}
# 00642490-v
# {':START_ID': '00047249-a', ':END_ID': '00047786-a', ':TYPE': 'wdo#antonym'}
# 00047249-a
# {':START_ID': '00048006-a', ':END_ID': '00048174-a', ':TYPE': 'wdo#antonym'}
# 00048006-a
# {':START_ID': '00364614-n', ':END_ID': '00361583-n', ':TYPE': 'wdo#antonym'}
# 00364614-n
# {':START_ID': '00048349-a', ':END_ID': '00050303-a', ':TYPE': 'wdo#antonym'}
# 00048349-a
# {':START_ID': '00050861-a', ':END_ID': '00051167-a', ':TYPE': 'wdo#antonym'}
# 00050861-a
# {':START_ID': '00003131-a', ':END_ID': '00002956-a', ':TYPE': 'wdo#antonym'}
# 00003131-a
# {':START_ID': '01451829-v', ':END_ID': '01452020-v', ':TYPE': 'wdo#antonym'}
# 01451829-v
# {':START_ID': '04799588-n', ':END_ID': '04800786-n', ':TYPE': 'wdo#antonym'}
# 04799588-n
# {':START_ID': '05119909-n', ':END_ID': '05120433-n', ':TYPE': 'wdo#antonym'}
# 05119909-n
# {':START_ID': '00051265-a', ':END_ID': '00051936-a', ':TYPE': 'wdo#antonym'}
# 00051265-a
# {':START_ID': '00371514-r', ':END_ID': '00371665-r', ':TYPE': 'wdo#antonym'}
# 00371514-r
# {':START_ID': '00052912-a', ':END_ID': '00055148-a', ':TYPE': 'wdo#antonym'}
# 00052912-a
# {':START_ID': '00747753-a', ':END_ID': '00747629-a', ':TYPE': 'wdo#antonym'}
# 00747753-a
# {':START_ID': '09203688-n', ':END_ID': '09203513-n', ':TYPE': 'wdo#antonym'}
# 09203688-n
# {':START_ID': '02614196-a', ':END_ID': '02610106-a', ':TYPE': 'wdo#antonym'}
# 02614196-a
# {':START_ID': '00055580-a', ':END_ID': '00055779-a', ':TYPE': 'wdo#antonym'}
# 00055580-a
# {':START_ID': '00351723-a', ':END_ID': '00352328-a', ':TYPE': 'wdo#antonym'}
# 00351723-a
# {':START_ID': '00352624-a', ':END_ID': '00352919-a', ':TYPE': 'wdo#antonym'}
# 00352624-a
# {':START_ID': '01831800-v', ':END_ID': '01832012-v', ':TYPE': 'wdo#antonym'}
# 01831800-v
# {':START_ID': '04800247-n', ':END_ID': '04801485-n', ':TYPE': 'wdo#antonym'}
# 04800247-n
# {':START_ID': '01766383-a', ':END_ID': '01767094-a', ':TYPE': 'wdo#antonym'}
# 01766383-a
# {':START_ID': '00818972-v', ':END_ID': '00818217-v', ':TYPE': 'wdo#antonym'}
# 00818972-v
# {':START_ID': '02454712-v', ':END_ID': '02454205-v', ':TYPE': 'wdo#antonym'}
# 02454712-v
# {':START_ID': '02508185-v', ':END_ID': '02508565-v', ':TYPE': 'wdo#antonym'}
# 02508185-v
# {':START_ID': '02493064-a', ':END_ID': '02493218-a', ':TYPE': 'wdo#antonym'}
# 02493064-a
# {':START_ID': '00056005-a', ':END_ID': '00056146-a', ':TYPE': 'wdo#antonym'}
# 00056005-a
# {':START_ID': '01037978-a', ':END_ID': '01037678-a', ':TYPE': 'wdo#antonym'}
# 01037978-a
# {':START_ID': '01409235-a', ':END_ID': '01408930-a', ':TYPE': 'wdo#antonym'}
# 01409235-a
# {':START_ID': '00056242-a', ':END_ID': '00060656-a', ':TYPE': 'wdo#antonym'}
# 00056242-a
# {':START_ID': '00061521-a', ':END_ID': '00063536-a', ':TYPE': 'wdo#antonym'}
# 00061521-a
# {':START_ID': '00056592-r', ':END_ID': '00056738-r', ':TYPE': 'wdo#antonym'}
# 00056592-r
# {':START_ID': '02358574-a', ':END_ID': '02358391-a', ':TYPE': 'wdo#antonym'}
# 02358574-a
# {':START_ID': '02358574-a', ':END_ID': '02358224-a', ':TYPE': 'wdo#antonym'}
# 02358574-a
# {':START_ID': '00008896-a', ':END_ID': '00008753-a', ':TYPE': 'wdo#antonym'}
# 00008896-a
# {':START_ID': '00008225-a', ':END_ID': '00008614-a', ':TYPE': 'wdo#antonym'}
# 00008225-a
# {':START_ID': '09628463-n', ':END_ID': '09645219-n', ':TYPE': 'wdo#antonym'}
# 09628463-n
# {':START_ID': '02124512-a', ':END_ID': '02124974-a', ':TYPE': 'wdo#antonym'}
# 02124512-a
# {':START_ID': '00282894-n', ':END_ID': '00055303-n', ':TYPE': 'wdo#antonym'}
# 00282894-n
# {':START_ID': '01996535-v', ':END_ID': '01998474-v', ':TYPE': 'wdo#antonym'}
# 01996535-v
# {':START_ID': '01997958-v', ':END_ID': '02001544-v', ':TYPE': 'wdo#antonym'}
# 01997958-v
# {':START_ID': '02518934-v', ':END_ID': '02519126-v', ':TYPE': 'wdo#antonym'}
# 02518934-v
# {':START_ID': '05163204-n', ':END_ID': '05169087-n', ':TYPE': 'wdo#antonym'}
# 05163204-n
# {':START_ID': '00064738-a', ':END_ID': '00065808-a', ':TYPE': 'wdo#antonym'}
# 00064738-a
# {':START_ID': '00014255-r', ':END_ID': '00014476-r', ':TYPE': 'wdo#antonym'}
# 00014255-r
# {':START_ID': '00066400-a', ':END_ID': '00067409-a', ':TYPE': 'wdo#antonym'}
# 00066400-a
# {':START_ID': '00154814-r', ':END_ID': '00239560-r', ':TYPE': 'wdo#antonym'}
# 00154814-r
# {':START_ID': '05167782-n', ':END_ID': '05172555-n', ':TYPE': 'wdo#antonym'}
# 05167782-n
# {':START_ID': '00067647-a', ':END_ID': '00068376-a', ':TYPE': 'wdo#antonym'}
# 00067647-a
# {':START_ID': '00069175-a', ':END_ID': '00069669-a', ':TYPE': 'wdo#antonym'}
# 00069175-a
# {':START_ID': '00069826-a', ':END_ID': '00070036-a', ':TYPE': 'wdo#antonym'}
# 00069826-a
# {':START_ID': '00070140-a', ':END_ID': '00071192-a', ':TYPE': 'wdo#antonym'}
# 00070140-a
# {':START_ID': '00016176-v', ':END_ID': '00015939-v', ':TYPE': 'wdo#antonym'}
# 00016176-v
# {':START_ID': '02737657-a', ':END_ID': '02737451-a', ':TYPE': 'wdo#antonym'}
# 02737657-a
# {':START_ID': '00071547-a', ':END_ID': '00072600-a', ':TYPE': 'wdo#antonym'}
# 00071547-a
# {':START_ID': '00073656-a', ':END_ID': '00074954-a', ':TYPE': 'wdo#antonym'}
# 00073656-a
# {':START_ID': '04794991-n', ':END_ID': '04793554-n', ':TYPE': 'wdo#antonym'}
# 04794991-n
# {':START_ID': '00334249-a', ':END_ID': '00334885-a', ':TYPE': 'wdo#antonym'}
# 00334249-a
# {':START_ID': '13835495-n', ':END_ID': '13835803-n', ':TYPE': 'wdo#antonym'}
# 13835495-n
# {':START_ID': '00667804-v', ':END_ID': '00668804-v', ':TYPE': 'wdo#antonym'}
# 00667804-v
# {':START_ID': '01188682-n', ':END_ID': '01188471-n', ':TYPE': 'wdo#antonym'}
# 01188682-n
# {':START_ID': '00075743-a', ':END_ID': '00076123-a', ':TYPE': 'wdo#antonym'}
# 00075743-a
# {':START_ID': '07218356-n', ':END_ID': '07219571-n', ':TYPE': 'wdo#antonym'}
# 07218356-n
# {':START_ID': '00159966-a', ':END_ID': '00160646-a', ':TYPE': 'wdo#antonym'}
# 00159966-a
# {':START_ID': '00077529-a', ':END_ID': '00078057-a', ':TYPE': 'wdo#antonym'}
# 00077529-a
# {':START_ID': '00078253-a', ':END_ID': '00082141-a', ':TYPE': 'wdo#antonym'}
# 00078253-a
# {':START_ID': '00276839-r', ':END_ID': '00277124-r', ':TYPE': 'wdo#antonym'}
# 00276839-r
# {':START_ID': '01037053-a', ':END_ID': '01036763-a', ':TYPE': 'wdo#antonym'}
# 01037053-a
# {':START_ID': '00250565-v', ':END_ID': '00251763-v', ':TYPE': 'wdo#antonym'}
# 00250565-v
# {':START_ID': '07960146-n', ':END_ID': '07960326-n', ':TYPE': 'wdo#antonym'}
# 07960146-n
# {':START_ID': '01310431-v', ':END_ID': '01310556-v', ':TYPE': 'wdo#antonym'}
# 01310431-v
# {':START_ID': '00082711-a', ':END_ID': '00085425-a', ':TYPE': 'wdo#antonym'}
# 00082711-a
# {':START_ID': '01766380-v', ':END_ID': '01768652-v', ':TYPE': 'wdo#antonym'}
# 01766380-v
# {':START_ID': '00085733-a', ':END_ID': '00087837-a', ':TYPE': 'wdo#antonym'}
# 00085733-a
# {':START_ID': '00088039-a', ':END_ID': '00089343-a', ':TYPE': 'wdo#antonym'}
# 00088039-a
# {':START_ID': '07528747-n', ':END_ID': '07530207-n', ':TYPE': 'wdo#antonym'}
# 07528747-n
# {':START_ID': '01308884-a', ':END_ID': '01308747-a', ':TYPE': 'wdo#antonym'}
# 01308884-a
# {':START_ID': '09798721-n', ':END_ID': '09792668-n', ':TYPE': 'wdo#antonym'}
# 09798721-n
# {':START_ID': '00807038-v', ':END_ID': '00806464-v', ':TYPE': 'wdo#antonym'}
# 00807038-v
# {':START_ID': '02663315-v', ':END_ID': '02724418-v', ':TYPE': 'wdo#antonym'}
# 02663315-v
# {':START_ID': '00089736-a', ':END_ID': '00090040-a', ':TYPE': 'wdo#antonym'}
# 00089736-a
# {':START_ID': '04648284-n', ':END_ID': '04650578-n', ':TYPE': 'wdo#antonym'}
# 04648284-n
# {':START_ID': '04786292-n', ':END_ID': '04787170-n', ':TYPE': 'wdo#antonym'}
# 04786292-n
# {':START_ID': '00220590-r', ':END_ID': '00313996-r', ':TYPE': 'wdo#antonym'}
# 00220590-r
# {':START_ID': '07189892-n', ':END_ID': '07195447-n', ':TYPE': 'wdo#antonym'}
# 07189892-n
# {':START_ID': '13994512-n', ':END_ID': '14005842-n', ':TYPE': 'wdo#antonym'}
# 13994512-n
# {':START_ID': '00078057-a', ':END_ID': '00077529-a', ':TYPE': 'wdo#antonym'}
# 00078057-a
# {':START_ID': '00075708-r', ':END_ID': '00074467-r', ':TYPE': 'wdo#antonym'}
# 00075708-r
# {':START_ID': '02931634-a', ':END_ID': '02931434-a', ':TYPE': 'wdo#antonym'}
# 02931634-a
# {':START_ID': '00091771-a', ':END_ID': '00091572-a', ':TYPE': 'wdo#antonym'}
# 00091771-a
# {':START_ID': '00091771-a', ':END_ID': '00091975-a', ':TYPE': 'wdo#antonym'}
# 00091771-a
# {':START_ID': '00091572-a', ':END_ID': '00091771-a', ':TYPE': 'wdo#antonym'}
# 00091572-a
# {':START_ID': '00091572-a', ':END_ID': '00091975-a', ':TYPE': 'wdo#antonym'}
# 00091572-a
# {':START_ID': '06635607-n', ':END_ID': '06635714-n', ':TYPE': 'wdo#antonym'}
# 06635607-n
# {':START_ID': '02095343-a', ':END_ID': '02095459-a', ':TYPE': 'wdo#antonym'}
# 02095343-a
# {':START_ID': '00194616-a', ':END_ID': '00198152-a', ':TYPE': 'wdo#antonym'}
# 00194616-a
# {':START_ID': '01162103-a', ':END_ID': '01163075-a', ':TYPE': 'wdo#antonym'}
# 01162103-a
# {':START_ID': '00092165-a', ':END_ID': '00093404-a', ':TYPE': 'wdo#antonym'}
# 00092165-a
# {':START_ID': '00093544-a', ':END_ID': '00093786-a', ':TYPE': 'wdo#antonym'}
# 00093544-a
# {':START_ID': '00094128-a', ':END_ID': '00094663-a', ':TYPE': 'wdo#antonym'}
# 00094128-a
# {':START_ID': '00465234-v', ':END_ID': '00467397-v', ':TYPE': 'wdo#antonym'}
# 00465234-v
# {':START_ID': '00735248-a', ':END_ID': '00735481-a', ':TYPE': 'wdo#antonym'}
# 00735248-a
# {':START_ID': '08310903-n', ':END_ID': '08311316-n', ':TYPE': 'wdo#antonym'}
# 08310903-n
# {':START_ID': '01413463-a', ':END_ID': '01413762-a', ':TYPE': 'wdo#antonym'}
# 01413463-a
# {':START_ID': '13756956-n', ':END_ID': '13756769-n', ':TYPE': 'wdo#antonym'}
# 13756956-n
# {':START_ID': '13756769-n', ':END_ID': '13756956-n', ':TYPE': 'wdo#antonym'}
# 13756769-n
# {':START_ID': '00095301-a', ':END_ID': '00096133-a', ':TYPE': 'wdo#antonym'}
# 00095301-a
# {':START_ID': '00025841-a', ':END_ID': '00025351-a', ':TYPE': 'wdo#antonym'}
# 00025841-a
# {':START_ID': '00025841-a', ':END_ID': '00026628-a', ':TYPE': 'wdo#antonym'}
# 00025841-a
# {':START_ID': '00027187-a', ':END_ID': '00026819-a', ':TYPE': 'wdo#antonym'}
# 00027187-a
# {':START_ID': '05046863-n', ':END_ID': '05046680-n', ':TYPE': 'wdo#antonym'}
# 05046863-n
# {':START_ID': '00265980-v', ':END_ID': '00265761-v', ':TYPE': 'wdo#antonym'}
# 00265980-v
# {':START_ID': '02277044-a', ':END_ID': '02276242-a', ':TYPE': 'wdo#antonym'}
# 02277044-a
# {':START_ID': '02277044-a', ':END_ID': '02275064-a', ':TYPE': 'wdo#antonym'}
# 02277044-a
# {':START_ID': '00181796-a', ':END_ID': '00181659-a', ':TYPE': 'wdo#antonym'}
# 00181796-a
# {':START_ID': '07452470-n', ':END_ID': '07453255-n', ':TYPE': 'wdo#antonym'}
# 07452470-n
# {':START_ID': '02606144-a', ':END_ID': '02606374-a', ':TYPE': 'wdo#antonym'}
# 02606144-a
# {':START_ID': '03084538-a', ':END_ID': '03084394-a', ':TYPE': 'wdo#antonym'}
# 03084538-a
# {':START_ID': '00711945-n', ':END_ID': '00712142-n', ':TYPE': 'wdo#antonym'}
# 00711945-n
# {':START_ID': '02385563-a', ':END_ID': '02385377-a', ':TYPE': 'wdo#antonym'}
# 02385563-a
# {':START_ID': '13982575-n', ':END_ID': '13982749-n', ':TYPE': 'wdo#antonym'}
# 13982575-n
# {':START_ID': '00803980-v', ':END_ID': '00797525-v', ':TYPE': 'wdo#antonym'}
# 00803980-v
# {':START_ID': '02260270-v', ':END_ID': '02217607-v', ':TYPE': 'wdo#antonym'}
# 02260270-v
# {':START_ID': '00101395-a', ':END_ID': '00101913-a', ':TYPE': 'wdo#antonym'}
# 00101395-a
# {':START_ID': '02624611-a', ':END_ID': '02624852-a', ':TYPE': 'wdo#antonym'}
# 02624611-a
# {':START_ID': '04748770-n', ':END_ID': '04749324-n', ':TYPE': 'wdo#antonym'}
# 04748770-n
# {':START_ID': '00350397-a', ':END_ID': '00350625-a', ':TYPE': 'wdo#antonym'}
# 00350397-a
# {':START_ID': '00353228-a', ':END_ID': '00354307-a', ':TYPE': 'wdo#antonym'}
# 00353228-a
# {':START_ID': '01667824-a', ':END_ID': '01667666-a', ':TYPE': 'wdo#antonym'}
# 01667824-a
# {':START_ID': '00767310-a', ':END_ID': '00767176-a', ':TYPE': 'wdo#antonym'}
# 00767310-a
# {':START_ID': '11444066-n', ':END_ID': '11467249-n', ':TYPE': 'wdo#antonym'}
# 11444066-n
# {':START_ID': '00102092-a', ':END_ID': '00102213-a', ':TYPE': 'wdo#antonym'}
# 00102092-a
# {':START_ID': '04840507-n', ':END_ID': '04842259-n', ':TYPE': 'wdo#antonym'}
# 04840507-n
# {':START_ID': '00102370-a', ':END_ID': '00102561-a', ':TYPE': 'wdo#antonym'}
# 00102370-a
# {':START_ID': '09806201-n', ':END_ID': '10500168-n', ':TYPE': 'wdo#antonym'}
# 09806201-n
# {':START_ID': '00215731-r', ':END_ID': '00215587-r', ':TYPE': 'wdo#antonym'}
# 00215731-r
# {':START_ID': '02037130-a', ':END_ID': '02036545-a', ':TYPE': 'wdo#antonym'}
# 02037130-a
# {':START_ID': '02037130-a', ':END_ID': '02035990-a', ':TYPE': 'wdo#antonym'}
# 02037130-a
# {':START_ID': '04832345-n', ':END_ID': '04829033-n', ':TYPE': 'wdo#antonym'}
# 04832345-n
# {':START_ID': '00103000-a', ':END_ID': '00104495-a', ':TYPE': 'wdo#antonym'}
# 00103000-a
# {':START_ID': '00221803-r', ':END_ID': '00221970-r', ':TYPE': 'wdo#antonym'}
# 00221803-r
# {':START_ID': '00104850-a', ':END_ID': '00105822-a', ':TYPE': 'wdo#antonym'}
# 00104850-a
# {':START_ID': '00263637-r', ':END_ID': '00263834-r', ':TYPE': 'wdo#antonym'}
# 00263637-r
# {':START_ID': '04629573-n', ':END_ID': '04629095-n', ':TYPE': 'wdo#antonym'}
# 04629573-n
# {':START_ID': '04629573-n', ':END_ID': '04629320-n', ':TYPE': 'wdo#antonym'}
# 04629573-n
# {':START_ID': '01354770-a', ':END_ID': '01354239-a', ':TYPE': 'wdo#antonym'}
# 01354770-a
# {':START_ID': '01354770-a', ':END_ID': '01353869-a', ':TYPE': 'wdo#antonym'}
# 01354770-a
# {':START_ID': '00355201-a', ':END_ID': '00355441-a', ':TYPE': 'wdo#antonym'}
# 00355201-a
# {':START_ID': '01512271-a', ':END_ID': '01512123-a', ':TYPE': 'wdo#antonym'}
# 01512271-a
# {':START_ID': '00106187-a', ':END_ID': '00106365-a', ':TYPE': 'wdo#antonym'}
# 00106187-a
# {':START_ID': '01249453-a', ':END_ID': '01247284-a', ':TYPE': 'wdo#antonym'}
# 01249453-a
# {':START_ID': '00126191-a', ':END_ID': '00124949-a', ':TYPE': 'wdo#antonym'}
# 00126191-a
# {':START_ID': '00126191-a', ':END_ID': '00125790-a', ':TYPE': 'wdo#antonym'}
# 00126191-a
# {':START_ID': '01033488-a', ':END_ID': '01033325-a', ':TYPE': 'wdo#antonym'}
# 01033488-a
# {':START_ID': '00026628-a', ':END_ID': '00025351-a', ':TYPE': 'wdo#antonym'}
# 00026628-a
# {':START_ID': '00026628-a', ':END_ID': '00025841-a', ':TYPE': 'wdo#antonym'}
# 00026628-a
# {':START_ID': '00106545-a', ':END_ID': '00107268-a', ':TYPE': 'wdo#antonym'}
# 00106545-a
# {':START_ID': '00180395-r', ':END_ID': '00398603-r', ':TYPE': 'wdo#antonym'}
# 00180395-r
# {':START_ID': '00398920-r', ':END_ID': '00398603-r', ':TYPE': 'wdo#antonym'}
# 00398920-r
# {':START_ID': '00110444-a', ':END_ID': '00110593-a', ':TYPE': 'wdo#antonym'}
# 00110444-a
# {':START_ID': '00108459-a', ':END_ID': '00108795-a', ':TYPE': 'wdo#antonym'}
# 00108459-a
# {':START_ID': '13451668-n', ':END_ID': '13464960-n', ':TYPE': 'wdo#antonym'}
# 13451668-n
# {':START_ID': '00109074-a', ':END_ID': '00109245-a', ':TYPE': 'wdo#antonym'}
# 00109074-a
# {':START_ID': '00110072-a', ':END_ID': '00110193-a', ':TYPE': 'wdo#antonym'}
# 00110072-a
# {':START_ID': '00110072-a', ':END_ID': '00110315-a', ':TYPE': 'wdo#antonym'}
# 00110072-a
# {':START_ID': '00069669-a', ':END_ID': '00069175-a', ':TYPE': 'wdo#antonym'}
# 00069669-a
# {':START_ID': '00070036-a', ':END_ID': '00069826-a', ':TYPE': 'wdo#antonym'}
# 00070036-a
# {':START_ID': '00110777-a', ':END_ID': '00111063-a', ':TYPE': 'wdo#antonym'}
# 00110777-a
# {':START_ID': '01223961-a', ':END_ID': '01223728-a', ':TYPE': 'wdo#antonym'}
# 01223961-a
# {':START_ID': '01223961-a', ':END_ID': '01223311-a', ':TYPE': 'wdo#antonym'}
# 01223961-a
# {':START_ID': '00111308-a', ':END_ID': '00111512-a', ':TYPE': 'wdo#antonym'}
# 00111308-a
# {':START_ID': '00101913-a', ':END_ID': '00101395-a', ':TYPE': 'wdo#antonym'}
# 00101913-a
# {':START_ID': '02624852-a', ':END_ID': '02624611-a', ':TYPE': 'wdo#antonym'}
# 02624852-a
# {':START_ID': '05780664-n', ':END_ID': '05791945-n', ':TYPE': 'wdo#antonym'}
# 05780664-n
# {':START_ID': '00111664-a', ':END_ID': '00111940-a', ':TYPE': 'wdo#antonym'}
# 00111664-a
# {':START_ID': '00112226-a', ':END_ID': '00112667-a', ':TYPE': 'wdo#antonym'}
# 00112226-a
# {':START_ID': '00113042-a', ':END_ID': '00113439-a', ':TYPE': 'wdo#antonym'}
# 00113042-a
# {':START_ID': '00645135-v', ':END_ID': '00645728-v', ':TYPE': 'wdo#antonym'}
# 00645135-v
# {':START_ID': '00418284-a', ':END_ID': '00418551-a', ':TYPE': 'wdo#antonym'}
# 00418284-a
# {':START_ID': '13452216-n', ':END_ID': '13526272-n', ':TYPE': 'wdo#antonym'}
# 13452216-n
# {':START_ID': '07503816-n', ':END_ID': '07503707-n', ':TYPE': 'wdo#antonym'}
# 07503816-n
# {':START_ID': '02145128-a', ':END_ID': '02144950-a', ':TYPE': 'wdo#antonym'}
# 02145128-a
# {':START_ID': '01664233-n', ':END_ID': '01664459-n', ':TYPE': 'wdo#antonym'}
# 01664233-n
# {':START_ID': '13452742-n', ':END_ID': '13555976-n', ':TYPE': 'wdo#antonym'}
# 13452742-n
# {':START_ID': '00109406-a', ':END_ID': '00109509-a', ':TYPE': 'wdo#antonym'}
# 00109406-a
# {':START_ID': '01033325-a', ':END_ID': '01033488-a', ':TYPE': 'wdo#antonym'}
# 01033325-a
# {':START_ID': '09811996-n', ':END_ID': '10026173-n', ':TYPE': 'wdo#antonym'}
# 09811996-n
# {':START_ID': '01481933-a', ':END_ID': '01481113-a', ':TYPE': 'wdo#antonym'}
# 01481933-a
# {':START_ID': '01481933-a', ':END_ID': '01479992-a', ':TYPE': 'wdo#antonym'}
# 01481933-a
# {':START_ID': '00198256-a', ':END_ID': '00198391-a', ':TYPE': 'wdo#antonym'}
# 00198256-a
# {':START_ID': '00021058-v', ':END_ID': '00022092-v', ':TYPE': 'wdo#antonym'}
# 00021058-v
# {':START_ID': '02145672-a', ':END_ID': '02145221-a', ':TYPE': 'wdo#antonym'}
# 02145672-a
# {':START_ID': '14061964-n', ':END_ID': '14061746-n', ':TYPE': 'wdo#antonym'}
# 14061964-n
# {':START_ID': '00114629-a', ':END_ID': '00117274-a', ':TYPE': 'wdo#antonym'}
# 00114629-a
# {':START_ID': '02055227-a', ':END_ID': '02051318-a', ':TYPE': 'wdo#antonym'}
# 02055227-a
# {':START_ID': '05078018-n', ':END_ID': '05080080-n', ':TYPE': 'wdo#antonym'}
# 05078018-n
# {':START_ID': '02566320-a', ':END_ID': '02566157-a', ':TYPE': 'wdo#antonym'}
# 02566320-a
# {':START_ID': '00118877-a', ':END_ID': '00119049-a', ':TYPE': 'wdo#antonym'}
# 00118877-a
# {':START_ID': '00121062-a', ':END_ID': '00121221-a', ':TYPE': 'wdo#antonym'}
# 00121062-a
# {':START_ID': '00119378-a', ':END_ID': '00120219-a', ':TYPE': 'wdo#antonym'}
# 00119378-a
# {':START_ID': '05012631-n', ':END_ID': '05013469-n', ':TYPE': 'wdo#antonym'}
# 05012631-n
# {':START_ID': '02941568-a', ':END_ID': '02941700-a', ':TYPE': 'wdo#antonym'}
# 02941568-a
# {':START_ID': '01364023-a', ':END_ID': '01363720-a', ':TYPE': 'wdo#antonym'}
# 01364023-a
# {':START_ID': '04924857-n', ':END_ID': '04924616-n', ':TYPE': 'wdo#antonym'}
# 04924857-n
# {':START_ID': '00681291-a', ':END_ID': '00681488-a', ':TYPE': 'wdo#antonym'}
# 00681291-a
# {':START_ID': '00681291-a', ':END_ID': '00681740-a', ':TYPE': 'wdo#antonym'}
# 00681291-a
# {':START_ID': '02717226-n', ':END_ID': '02988154-n', ':TYPE': 'wdo#antonym'}
# 02717226-n
# {':START_ID': '02717446-n', ':END_ID': '02988392-n', ':TYPE': 'wdo#antonym'}
# 02717446-n
# {':START_ID': '02637246-a', ':END_ID': '02637412-a', ':TYPE': 'wdo#antonym'}
# 02637246-a
# {':START_ID': '00121384-a', ':END_ID': '00121844-a', ':TYPE': 'wdo#antonym'}
# 00121384-a
# {':START_ID': '13453616-n', ':END_ID': '13551440-n', ':TYPE': 'wdo#antonym'}
# 13453616-n
# {':START_ID': '07215187-n', ':END_ID': '07208256-n', ':TYPE': 'wdo#antonym'}
# 07215187-n
# {':START_ID': '02717794-n', ':END_ID': '04383346-n', ':TYPE': 'wdo#antonym'}
# 02717794-n
# {':START_ID': '09792668-n', ':END_ID': '09798721-n', ':TYPE': 'wdo#antonym'}
# 09792668-n
# {':START_ID': '00626239-a', ':END_ID': '00626030-a', ':TYPE': 'wdo#antonym'}
# 00626239-a
# {':START_ID': '00764121-a', ':END_ID': '00763096-a', ':TYPE': 'wdo#antonym'}
# 00764121-a
# {':START_ID': '08512259-n', ':END_ID': '08511997-n', ':TYPE': 'wdo#antonym'}
# 08512259-n
# {':START_ID': '00122675-a', ':END_ID': '00123436-a', ':TYPE': 'wdo#antonym'}
# 00122675-a
# {':START_ID': '00131484-a', ':END_ID': '00131668-a', ':TYPE': 'wdo#antonym'}
# 00131484-a
# {':START_ID': '00122362-a', ':END_ID': '00122459-a', ':TYPE': 'wdo#antonym'}
# 00122362-a
# {':START_ID': '00131850-a', ':END_ID': '00132498-a', ':TYPE': 'wdo#antonym'}
# 00131850-a
# {':START_ID': '05085496-n', ':END_ID': '05085657-n', ':TYPE': 'wdo#antonym'}
# 05085496-n
# {':START_ID': '00131353-a', ':END_ID': '00131223-a', ':TYPE': 'wdo#antonym'}
# 00131353-a
# {':START_ID': '01822909-a', ':END_ID': '01822805-a', ':TYPE': 'wdo#antonym'}
# 01822909-a
# {':START_ID': '02939116-a', ':END_ID': '02939257-a', ':TYPE': 'wdo#antonym'}
# 02939116-a
# {':START_ID': '14749203-n', ':END_ID': '14747789-n', ':TYPE': 'wdo#antonym'}
# 14749203-n
# {':START_ID': '00061347-a', ':END_ID': '00061228-a', ':TYPE': 'wdo#antonym'}
# 00061347-a
# {':START_ID': '02497584-a', ':END_ID': '02497396-a', ':TYPE': 'wdo#antonym'}
# 02497584-a
# {':START_ID': '00109827-a', ':END_ID': '00109944-a', ':TYPE': 'wdo#antonym'}
# 00109827-a
# {':START_ID': '14544623-n', ':END_ID': '14544904-n', ':TYPE': 'wdo#antonym'}
# 14544623-n
# {':START_ID': '01473056-a', ':END_ID': '01472592-a', ':TYPE': 'wdo#antonym'}
# 01473056-a
# {':START_ID': '08515760-n', ':END_ID': '08515608-n', ':TYPE': 'wdo#antonym'}
# 08515760-n
# {':START_ID': '01173680-a', ':END_ID': '01173613-a', ':TYPE': 'wdo#antonym'}
# 01173680-a
# {':START_ID': '02122604-a', ':END_ID': '02121107-a', ':TYPE': 'wdo#antonym'}
# 02122604-a
# {':START_ID': '05849538-n', ':END_ID': '05848697-n', ':TYPE': 'wdo#antonym'}
# 05849538-n
# {':START_ID': '06298695-n', ':END_ID': '06314672-n', ':TYPE': 'wdo#antonym'}
# 06298695-n
# {':START_ID': '02390332-a', ':END_ID': '02389870-a', ':TYPE': 'wdo#antonym'}
# 02390332-a
# {':START_ID': '00124525-a', ':END_ID': '00124676-a', ':TYPE': 'wdo#antonym'}
# 00124525-a
# {':START_ID': '01977529-a', ':END_ID': '01974305-a', ':TYPE': 'wdo#antonym'}
# 01977529-a
# {':START_ID': '01781077-a', ':END_ID': '01780085-a', ':TYPE': 'wdo#antonym'}
# 01781077-a
# {':START_ID': '08511997-n', ':END_ID': '08512259-n', ':TYPE': 'wdo#antonym'}
# 08511997-n
# {':START_ID': '08512918-n', ':END_ID': '08636406-n', ':TYPE': 'wdo#antonym'}
# 08512918-n
# {':START_ID': '07503707-n', ':END_ID': '07503816-n', ':TYPE': 'wdo#antonym'}
# 07503707-n
# {':START_ID': '02144950-a', ':END_ID': '02145128-a', ':TYPE': 'wdo#antonym'}
# 02144950-a
# {':START_ID': '01837064-a', ':END_ID': '01836664-a', ':TYPE': 'wdo#antonym'}
# 01837064-a
# {':START_ID': '08512627-n', ':END_ID': '08635954-n', ':TYPE': 'wdo#antonym'}
# 08512627-n
# {':START_ID': '00114287-a', ':END_ID': '00114474-a', ':TYPE': 'wdo#antonym'}
# 00114287-a
# {':START_ID': '00099382-a', ':END_ID': '00099589-a', ':TYPE': 'wdo#antonym'}
# 00099382-a
# {':START_ID': '08512430-n', ':END_ID': '08636244-n', ':TYPE': 'wdo#antonym'}
# 08512430-n
# {':START_ID': '08513105-n', ':END_ID': '08636581-n', ':TYPE': 'wdo#antonym'}
# 08513105-n
# {':START_ID': '01635891-a', ':END_ID': '01636454-a', ':TYPE': 'wdo#antonym'}
# 01635891-a
# {':START_ID': '08513209-n', ':END_ID': '08636687-n', ':TYPE': 'wdo#antonym'}
# 08513209-n
# {':START_ID': '05950822-n', ':END_ID': '05951187-n', ':TYPE': 'wdo#antonym'}
# 05950822-n
# {':START_ID': '05950822-n', ':END_ID': '05951428-n', ':TYPE': 'wdo#antonym'}
# 05950822-n
# {':START_ID': '08513209-n', ':END_ID': '08636687-n', ':TYPE': 'wdo#antonym'}
# 08513209-n
# {':START_ID': '00133920-a', ':END_ID': '00134136-a', ':TYPE': 'wdo#antonym'}
# 00133920-a
# {':START_ID': '00171619-a', ':END_ID': '00172305-a', ':TYPE': 'wdo#antonym'}
# 00171619-a
# {':START_ID': '00263125-r', ':END_ID': '00263256-r', ':TYPE': 'wdo#antonym'}
# 00263125-r
# {':START_ID': '00423043-v', ':END_ID': '00427911-v', ':TYPE': 'wdo#antonym'}
# 00423043-v
# {':START_ID': '00426024-v', ':END_ID': '00428350-v', ':TYPE': 'wdo#antonym'}
# 00426024-v
# {':START_ID': '00051015-n', ':END_ID': '00054429-n', ':TYPE': 'wdo#antonym'}
# 00051015-n
# {':START_ID': '07336372-n', ':END_ID': '07350316-n', ':TYPE': 'wdo#antonym'}
# 07336372-n
# {':START_ID': '00134330-a', ':END_ID': '00134406-a', ':TYPE': 'wdo#antonym'}
# 00134330-a
# {':START_ID': '00134488-a', ':END_ID': '00134922-a', ':TYPE': 'wdo#antonym'}
# 00134488-a
# {':START_ID': '05002696-n', ':END_ID': '05003988-n', ':TYPE': 'wdo#antonym'}
# 05002696-n
# {':START_ID': '00863593-v', ':END_ID': '00863889-v', ':TYPE': 'wdo#antonym'}
# 00863593-v
# {':START_ID': '13817392-n', ':END_ID': '13818265-n', ':TYPE': 'wdo#antonym'}
# 13817392-n
# {':START_ID': '00866236-a', ':END_ID': '00865514-a', ':TYPE': 'wdo#antonym'}
# 00866236-a
# {':START_ID': '00850001-a', ':END_ID': '00849591-a', ':TYPE': 'wdo#antonym'}
# 00850001-a
# {':START_ID': '04723767-n', ':END_ID': '04728704-n', ':TYPE': 'wdo#antonym'}
# 04723767-n
# {':START_ID': '00316406-v', ':END_ID': '00316131-v', ':TYPE': 'wdo#antonym'}
# 00316406-v
# {':START_ID': '00316996-v', ':END_ID': '00315821-v', ':TYPE': 'wdo#antonym'}
# 00316996-v
# {':START_ID': '00365266-n', ':END_ID': '00365426-n', ':TYPE': 'wdo#antonym'}
# 00365266-n
# {':START_ID': '00272695-r', ':END_ID': '00272901-r', ':TYPE': 'wdo#antonym'}
# 00272695-r
# {':START_ID': '04663006-n', ':END_ID': '04664601-n', ':TYPE': 'wdo#antonym'}
# 04663006-n
# {':START_ID': '00135131-a', ':END_ID': '00135472-a', ':TYPE': 'wdo#antonym'}
# 00135131-a
# {':START_ID': '00688934-v', ':END_ID': '00689082-v', ':TYPE': 'wdo#antonym'}
# 00688934-v
# {':START_ID': '06699923-n', ':END_ID': '06722631-n', ':TYPE': 'wdo#antonym'}
# 06699923-n
# {':START_ID': '00135772-a', ':END_ID': '00136789-a', ':TYPE': 'wdo#antonym'}
# 00135772-a
# {':START_ID': '00140318-r', ':END_ID': '00140793-r', ':TYPE': 'wdo#antonym'}
# 00140318-r
# {':START_ID': '04723223-n', ':END_ID': '04728926-n', ':TYPE': 'wdo#antonym'}
# 04723223-n
# {':START_ID': '04906208-n', ':END_ID': '04909173-n', ':TYPE': 'wdo#antonym'}
# 04906208-n
# {':START_ID': '01217882-n', ':END_ID': '00876299-n', ':TYPE': 'wdo#antonym'}
# 01217882-n
# {':START_ID': '06699481-n', ':END_ID': '06722472-n', ':TYPE': 'wdo#antonym'}
# 06699481-n
# {':START_ID': '07515398-n', ':END_ID': '07518068-n', ':TYPE': 'wdo#antonym'}
# 07515398-n
# {':START_ID': '00675902-v', ':END_ID': '00676259-v', ':TYPE': 'wdo#antonym'}
# 00675902-v
# {':START_ID': '00808164-v', ':END_ID': '00808840-v', ':TYPE': 'wdo#antonym'}
# 00808164-v
# {':START_ID': '00263397-r', ':END_ID': '00263521-r', ':TYPE': 'wdo#antonym'}
# 00263397-r
# {':START_ID': '00139437-a', ':END_ID': '00139890-a', ':TYPE': 'wdo#antonym'}
# 00139437-a
# {':START_ID': '00140612-a', ':END_ID': '00141138-a', ':TYPE': 'wdo#antonym'}
# 00140612-a
# {':START_ID': '05630239-n', ':END_ID': '05655488-n', ':TYPE': 'wdo#antonym'}
# 05630239-n
# {':START_ID': '04723767-n', ':END_ID': '04728704-n', ':TYPE': 'wdo#antonym'}
# 04723767-n
# {':START_ID': '00124949-a', ':END_ID': '00126191-a', ':TYPE': 'wdo#antonym'}
# 00124949-a
# {':START_ID': '00124949-a', ':END_ID': '00125790-a', ':TYPE': 'wdo#antonym'}
# 00124949-a
# {':START_ID': '01357937-a', ':END_ID': '01357773-a', ':TYPE': 'wdo#antonym'}
# 01357937-a
# {':START_ID': '00141501-a', ':END_ID': '00141705-a', ':TYPE': 'wdo#antonym'}
# 00141501-a
# {':START_ID': '00722368-a', ':END_ID': '00723526-a', ':TYPE': 'wdo#antonym'}
# 00722368-a
# {':START_ID': '00143086-a', ':END_ID': '00143215-a', ':TYPE': 'wdo#antonym'}
# 00143086-a
# {':START_ID': '00143308-a', ':END_ID': '00143538-a', ':TYPE': 'wdo#antonym'}
# 00143308-a
# {':START_ID': '00143538-a', ':END_ID': '00143308-a', ':TYPE': 'wdo#antonym'}
# 00143538-a
# {':START_ID': '00606011-a', ':END_ID': '00607043-a', ':TYPE': 'wdo#antonym'}
# 00606011-a
# {':START_ID': '01987278-v', ':END_ID': '01989043-v', ':TYPE': 'wdo#antonym'}
# 01987278-v
# {':START_ID': '01987278-v', ':END_ID': '01988916-v', ':TYPE': 'wdo#antonym'}
# 01987278-v
# {':START_ID': '01089608-v', ':END_ID': '01090246-v', ':TYPE': 'wdo#antonym'}
# 01089608-v
# {':START_ID': '01159386-n', ':END_ID': '01160044-n', ':TYPE': 'wdo#antonym'}
# 01159386-n
# {':START_ID': '00143675-a', ':END_ID': '00144185-a', ':TYPE': 'wdo#antonym'}
# 00143675-a
# {':START_ID': '00146145-a', ':END_ID': '00147263-a', ':TYPE': 'wdo#antonym'}
# 00146145-a
# {':START_ID': '00147478-a', ':END_ID': '00148054-a', ':TYPE': 'wdo#antonym'}
# 00147478-a
# {':START_ID': '01159386-n', ':END_ID': '01160044-n', ':TYPE': 'wdo#antonym'}
# 01159386-n
# {':START_ID': '00148054-a', ':END_ID': '00147478-a', ':TYPE': 'wdo#antonym'}
# 00148054-a
# {':START_ID': '00144857-a', ':END_ID': '00145996-a', ':TYPE': 'wdo#antonym'}
# 00144857-a
# {':START_ID': '00148151-a', ':END_ID': '00148796-a', ':TYPE': 'wdo#antonym'}
# 00148151-a
# {':START_ID': '01466592-v', ':END_ID': '01469362-v', ':TYPE': 'wdo#antonym'}
# 01466592-v
# {':START_ID': '01685687-a', ':END_ID': '01686267-a', ':TYPE': 'wdo#antonym'}
# 01685687-a
# {':START_ID': '02009962-v', ':END_ID': '02013448-v', ':TYPE': 'wdo#antonym'}
# 02009962-v
# {':START_ID': '00099786-a', ':END_ID': '00099950-a', ':TYPE': 'wdo#antonym'}
# 00099786-a
# {':START_ID': '00149002-a', ':END_ID': '00151129-a', ':TYPE': 'wdo#antonym'}
# 00149002-a
# {':START_ID': '04883900-n', ':END_ID': '04879871-n', ':TYPE': 'wdo#antonym'}
# 04883900-n
# {':START_ID': '00151470-a', ':END_ID': '00152373-a', ':TYPE': 'wdo#antonym'}
# 00151470-a
# {':START_ID': '00154678-a', ':END_ID': '00154919-a', ':TYPE': 'wdo#antonym'}
# 00154678-a
# {':START_ID': '00269743-r', ':END_ID': '00269895-r', ':TYPE': 'wdo#antonym'}
# 00269743-r
# {':START_ID': '00329241-r', ':END_ID': '00329418-r', ':TYPE': 'wdo#antonym'}
# 00329241-r
# {':START_ID': '00022119-n', ':END_ID': '00019308-n', ':TYPE': 'wdo#antonym'}
# 00022119-n
# {':START_ID': '01575756-a', ':END_ID': '01575285-a', ':TYPE': 'wdo#antonym'}
# 01575756-a
# {':START_ID': '06907583-n', ':END_ID': '06916947-n', ':TYPE': 'wdo#antonym'}
# 06907583-n
# {':START_ID': '00141600-r', ':END_ID': '00141437-r', ':TYPE': 'wdo#antonym'}
# 00141600-r
# {':START_ID': '00151129-a', ':END_ID': '00149002-a', ':TYPE': 'wdo#antonym'}
# 00151129-a
# {':START_ID': '04879871-n', ':END_ID': '04883900-n', ':TYPE': 'wdo#antonym'}
# 04879871-n
# {':START_ID': '01973223-v', ':END_ID': '01974840-v', ':TYPE': 'wdo#antonym'}
# 01973223-v
# {':START_ID': '02493886-a', ':END_ID': '02495328-a', ':TYPE': 'wdo#antonym'}
# 02493886-a
# {':START_ID': '08515307-n', ':END_ID': '08566499-n', ':TYPE': 'wdo#antonym'}
# 08515307-n
# {':START_ID': '09229873-n', ':END_ID': '09288526-n', ':TYPE': 'wdo#antonym'}
# 09229873-n
# {':START_ID': '02143325-a', ':END_ID': '02142650-a', ':TYPE': 'wdo#antonym'}
# 02143325-a
# {':START_ID': '00155165-a', ':END_ID': '00156232-a', ':TYPE': 'wdo#antonym'}
# 00155165-a
# {':START_ID': '00267823-r', ':END_ID': '00210827-r', ':TYPE': 'wdo#antonym'}
# 00267823-r
# {':START_ID': '00189224-a', ':END_ID': '00188104-a', ':TYPE': 'wdo#antonym'}
# 00189224-a
# {':START_ID': '01660471-v', ':END_ID': '01661660-v', ':TYPE': 'wdo#antonym'}
# 01660471-v
# {':START_ID': '00913832-n', ':END_ID': '00914105-n', ':TYPE': 'wdo#antonym'}
# 00913832-n
# {':START_ID': '01232427-n', ':END_ID': '00914105-n', ':TYPE': 'wdo#antonym'}
# 01232427-n
# {':START_ID': '00805801-v', ':END_ID': '00806315-v', ':TYPE': 'wdo#antonym'}
# 00805801-v
# {':START_ID': '00157368-a', ':END_ID': '00158105-a', ':TYPE': 'wdo#antonym'}
# 00157368-a
# {':START_ID': '00267920-r', ':END_ID': '00268077-r', ':TYPE': 'wdo#antonym'}
# 00267920-r
# {':START_ID': '05161764-n', ':END_ID': '05168909-n', ':TYPE': 'wdo#antonym'}
# 05161764-n
# {':START_ID': '00850483-a', ':END_ID': '00850845-a', ':TYPE': 'wdo#antonym'}
# 00850483-a
# {':START_ID': '00159450-v', ':END_ID': '00160461-v', ':TYPE': 'wdo#antonym'}
# 00159450-v
# {':START_ID': '00160069-v', ':END_ID': '00160688-v', ':TYPE': 'wdo#antonym'}
# 00160069-v
# {':START_ID': '00160255-v', ':END_ID': '00160820-v', ':TYPE': 'wdo#antonym'}
# 00160255-v
# {':START_ID': '02362263-a', ':END_ID': '02362685-a', ':TYPE': 'wdo#antonym'}
# 02362263-a
# {':START_ID': '00715072-v', ':END_ID': '00716178-v', ':TYPE': 'wdo#antonym'}
# 00715072-v
# {':START_ID': '14444543-n', ':END_ID': '14444777-n', ':TYPE': 'wdo#antonym'}
# 14444543-n
# {':START_ID': '00158655-a', ':END_ID': '00159114-a', ':TYPE': 'wdo#antonym'}
# 00158655-a
# {':START_ID': '00849400-n', ':END_ID': '00849562-n', ':TYPE': 'wdo#antonym'}
# 00849400-n
# {':START_ID': '00109509-a', ':END_ID': '00109406-a', ':TYPE': 'wdo#antonym'}
# 00109509-a
# {':START_ID': '13961932-n', ':END_ID': '13961696-n', ':TYPE': 'wdo#antonym'}
# 13961932-n
# {':START_ID': '02656537-a', ':END_ID': '02656145-a', ':TYPE': 'wdo#antonym'}
# 02656537-a
# {':START_ID': '02318451-a', ':END_ID': '02318213-a', ':TYPE': 'wdo#antonym'}
# 02318451-a
# {':START_ID': '00191068-a', ':END_ID': '00191511-a', ':TYPE': 'wdo#antonym'}
# 00191068-a
# {':START_ID': '02382167-a', ':END_ID': '02380286-a', ':TYPE': 'wdo#antonym'}
# 02382167-a
# {':START_ID': '00177264-r', ':END_ID': '00177127-r', ':TYPE': 'wdo#antonym'}
# 00177264-r
# {':START_ID': '05072886-n', ':END_ID': '05071996-n', ':TYPE': 'wdo#antonym'}
# 05072886-n
# {':START_ID': '13868035-n', ':END_ID': '13867436-n', ':TYPE': 'wdo#antonym'}
# 13868035-n
# {':START_ID': '02388163-a', ':END_ID': '02386219-a', ':TYPE': 'wdo#antonym'}
# 02388163-a
# {':START_ID': '02389387-a', ':END_ID': '02389133-a', ':TYPE': 'wdo#antonym'}
# 02389387-a
# {':START_ID': '13456550-n', ':END_ID': '13585704-n', ':TYPE': 'wdo#antonym'}
# 13456550-n
# {':START_ID': '02389757-a', ':END_ID': '02389657-a', ':TYPE': 'wdo#antonym'}
# 02389757-a
# {':START_ID': '00106462-r', ':END_ID': '00106595-r', ':TYPE': 'wdo#antonym'}
# 00106462-r
# {':START_ID': '00105032-r', ':END_ID': '00105215-r', ':TYPE': 'wdo#antonym'}
# 00105032-r
# {':START_ID': '00105215-r', ':END_ID': '00105032-r', ':TYPE': 'wdo#antonym'}
# 00105215-r
# {':START_ID': '00105032-r', ':END_ID': '00105215-r', ':TYPE': 'wdo#antonym'}
# 00105032-r
# {':START_ID': '00105215-r', ':END_ID': '00105032-r', ':TYPE': 'wdo#antonym'}
# 00105215-r
# {':START_ID': '00106595-r', ':END_ID': '00106462-r', ':TYPE': 'wdo#antonym'}
# 00106595-r
# {':START_ID': '05989123-n', ':END_ID': '06233395-n', ':TYPE': 'wdo#antonym'}
# 05989123-n
# {':START_ID': '06112083-n', ':END_ID': '06112472-n', ':TYPE': 'wdo#antonym'}
# 06112083-n
# {':START_ID': '01685495-a', ':END_ID': '01685348-a', ':TYPE': 'wdo#antonym'}
# 01685495-a
# {':START_ID': '02447392-a', ':END_ID': '02446352-a', ':TYPE': 'wdo#antonym'}
# 02447392-a
# {':START_ID': '06877064-n', ':END_ID': '06876801-n', ':TYPE': 'wdo#antonym'}
# 06877064-n
# {':START_ID': '02328637-a', ':END_ID': '02328429-a', ':TYPE': 'wdo#antonym'}
# 02328637-a
# {':START_ID': '14569447-n', ':END_ID': '14568274-n', ':TYPE': 'wdo#antonym'}
# 14569447-n
# {':START_ID': '00557099-a', ':END_ID': '00557337-a', ':TYPE': 'wdo#antonym'}
# 00557099-a
# {':START_ID': '01293025-v', ':END_ID': '01302344-v', ':TYPE': 'wdo#antonym'}
# 01293025-v
# {':START_ID': '01299048-v', ':END_ID': '01301254-v', ':TYPE': 'wdo#antonym'}
# 01299048-v
# {':START_ID': '00162696-a', ':END_ID': '00163348-a', ':TYPE': 'wdo#antonym'}
# 00162696-a
# {':START_ID': '00159190-a', ':END_ID': '00159672-a', ':TYPE': 'wdo#antonym'}
# 00159190-a
# {':START_ID': '00161690-a', ':END_ID': '00161838-a', ':TYPE': 'wdo#antonym'}
# 00161690-a
# {':START_ID': '01121587-v', ':END_ID': '01130221-v', ':TYPE': 'wdo#antonym'}
# 01121587-v
# {':START_ID': '02618797-v', ':END_ID': '02619707-v', ':TYPE': 'wdo#antonym'}
# 02618797-v
# {':START_ID': '00618360-v', ':END_ID': '00616690-v', ':TYPE': 'wdo#antonym'}
# 00618360-v
# ...
# {':START_ID': '00163651-a', ':END_ID': '00164255-a', ':TYPE': 'wdo#antonym'}
# 00163651-a
# {':START_ID': '02544282-a', ':END_ID': '02544717-a', ':TYPE': 'wdo#antonym'}
# 02544282-a
# {':START_ID': '02273196-v', ':END_ID': '02273988-v', ':TYPE': 'wdo#antonym'}
# 02273196-v
# {':START_ID': '02430842-a', ':END_ID': '02429932-a', ':TYPE': 'wdo#antonym'}
# 02430842-a
# {':START_ID': '06115480-n', ':END_ID': '06115691-n', ':TYPE': 'wdo#antonym'}
# 06115480-n
# {':START_ID': '06115480-n', ':END_ID': '06115691-n', ':TYPE': 'wdo#antonym'}
# 06115480-n
# {':START_ID': '00434185-v', ':END_ID': '00434886-v', ':TYPE': 'wdo#antonym'}
# 00434185-v
# {':START_ID': '00434478-v', ':END_ID': '00434731-v', ':TYPE': 'wdo#antonym'}
# 00434478-v
# {':START_ID': '02544787-a', ':END_ID': '02544889-a', ':TYPE': 'wdo#antonym'}
# 02544787-a
# {':START_ID': '02544973-a', ':END_ID': '02545162-a', ':TYPE': 'wdo#antonym'}
# 02544973-a
# {':START_ID': '07429166-n', ':END_ID': '07437601-n', ':TYPE': 'wdo#antonym'}
# 07429166-n
# {':START_ID': '02332106-a', ':END_ID': '02328781-a', ':TYPE': 'wdo#antonym'}
# 02332106-a
# {':START_ID': '05049437-n', ':END_ID': '05037315-n', ':TYPE': 'wdo#antonym'}
# 05049437-n
# {':START_ID': '05166989-n', ':END_ID': '05166608-n', ':TYPE': 'wdo#antonym'}
# 05166989-n
# {':START_ID': '00223926-v', ':END_ID': '00220887-v', ':TYPE': 'wdo#antonym'}
# 00223926-v
# {':START_ID': '00225327-v', ':END_ID': '00221295-v', ':TYPE': 'wdo#antonym'}
# 00225327-v
# {':START_ID': '00363181-n', ':END_ID': '00374871-n', ':TYPE': 'wdo#antonym'}
# 00363181-n
# {':START_ID': '07441937-n', ':END_ID': '07441824-n', ':TYPE': 'wdo#antonym'}
# 07441937-n
# {':START_ID': '00178969-r', ':END_ID': '00178775-r', ':TYPE': 'wdo#antonym'}
# 00178969-r
# {':START_ID': '05047429-n', ':END_ID': '05036872-n', ':TYPE': 'wdo#antonym'}
# 05047429-n
# {':START_ID': '14498302-n', ':END_ID': '14498140-n', ':TYPE': 'wdo#antonym'}
# 14498302-n
# {':START_ID': '14514855-n', ':END_ID': '14516729-n', ':TYPE': 'wdo#antonym'}
# 14514855-n
# {':START_ID': '02549778-a', ':END_ID': '02549967-a', ':TYPE': 'wdo#antonym'}
# 02549778-a
# {':START_ID': '02550103-a', ':END_ID': '02550320-a', ':TYPE': 'wdo#antonym'}
# 02550103-a
# {':START_ID': '01521557-v', ':END_ID': '01521954-v', ':TYPE': 'wdo#antonym'}
# 01521557-v
# {':START_ID': '02601403-a', ':END_ID': '02601687-a', ':TYPE': 'wdo#antonym'}
# 02601403-a
# {':START_ID': '13105873-n', ':END_ID': '13105753-n', ':TYPE': 'wdo#antonym'}
# 13105873-n
# {':START_ID': '02550621-a', ':END_ID': '02550461-a', ':TYPE': 'wdo#antonym'}
# 02550621-a
# {':START_ID': '02550461-a', ':END_ID': '02550621-a', ':TYPE': 'wdo#antonym'}
# 02550461-a
# {':START_ID': '01818233-v', ':END_ID': '01818041-v', ':TYPE': 'wdo#antonym'}
# 01818233-v
# {':START_ID': '01191320-a', ':END_ID': '01191154-a', ':TYPE': 'wdo#antonym'}
# 01191320-a
# {':START_ID': '01191154-a', ':END_ID': '01191320-a', ':TYPE': 'wdo#antonym'}
# 01191154-a
# {':START_ID': '00902346-v', ':END_ID': '00902724-v', ':TYPE': 'wdo#antonym'}
# 00902346-v
# {':START_ID': '02550712-a', ':END_ID': '02550980-a', ':TYPE': 'wdo#antonym'}
# 02550712-a
# {':START_ID': '00011555-r', ':END_ID': '00011978-r', ':TYPE': 'wdo#antonym'}
# 00011555-r
# {':START_ID': '00012591-r', ':END_ID': '00012748-r', ':TYPE': 'wdo#antonym'}
# 00012591-r
# {':START_ID': '00013554-r', ':END_ID': '00013698-r', ':TYPE': 'wdo#antonym'}
# 00013554-r
# {':START_ID': '00014255-r', ':END_ID': '00014476-r', ':TYPE': 'wdo#antonym'}
# 00014255-r
# {':START_ID': '00015078-r', ':END_ID': '00015200-r', ':TYPE': 'wdo#antonym'}
# 00015078-r
# {':START_ID': '02551348-a', ':END_ID': '02552072-a', ':TYPE': 'wdo#antonym'}
# 02551348-a
# {':START_ID': '00068575-a', ':END_ID': '00068887-a', ':TYPE': 'wdo#antonym'}
# 00068575-a
# {':START_ID': '14470991-n', ':END_ID': '14471666-n', ':TYPE': 'wdo#antonym'}
# 14470991-n
# {':START_ID': '00701368-a', ':END_ID': '00701533-a', ':TYPE': 'wdo#antonym'}
# 00701368-a
# {':START_ID': '14471374-n', ':END_ID': '14085287-n', ':TYPE': 'wdo#antonym'}
# 14471374-n
# {':START_ID': '14471374-n', ':END_ID': '14085287-n', ':TYPE': 'wdo#antonym'}
# 14471374-n
# {':START_ID': '00827889-a', ':END_ID': '00826918-a', ':TYPE': 'wdo#antonym'}
# 00827889-a
# {':START_ID': '00325751-r', ':END_ID': '00325628-r', ':TYPE': 'wdo#antonym'}
# 00325751-r
# {':START_ID': '00828657-a', ':END_ID': '00829153-a', ':TYPE': 'wdo#antonym'}
# 00828657-a
# {':START_ID': '00829509-a', ':END_ID': '00830498-a', ':TYPE': 'wdo#antonym'}
# 00829509-a
# {':START_ID': '00215377-v', ':END_ID': '00218901-v', ':TYPE': 'wdo#antonym'}
# 00215377-v
# {':START_ID': '02558087-a', ':END_ID': '02562150-a', ':TYPE': 'wdo#antonym'}
# 02558087-a
# {':START_ID': '02565037-a', ':END_ID': '02565316-a', ':TYPE': 'wdo#antonym'}
# 02565037-a
# {':START_ID': '02565522-a', ':END_ID': '02565710-a', ':TYPE': 'wdo#antonym'}
# 02565522-a
# {':START_ID': '02565896-a', ':END_ID': '02566037-a', ':TYPE': 'wdo#antonym'}
# 02565896-a
# {':START_ID': '04580911-n', ':END_ID': '03255803-n', ':TYPE': 'wdo#antonym'}
# 04580911-n
# {':START_ID': '04581223-n', ':END_ID': '03256635-n', ':TYPE': 'wdo#antonym'}
# 04581223-n
# {':START_ID': '14558298-n', ':END_ID': '14560040-n', ':TYPE': 'wdo#antonym'}
# 14558298-n
# {':START_ID': '02566453-a', ':END_ID': '02566547-a', ':TYPE': 'wdo#antonym'}
# 02566453-a
# {':START_ID': '02566547-a', ':END_ID': '02566453-a', ':TYPE': 'wdo#antonym'}
# 02566547-a
# {':START_ID': '00917783-v', ':END_ID': '00914426-v', ':TYPE': 'wdo#antonym'}
# 00917783-v
# {':START_ID': '00244146-a', ':END_ID': '00243558-a', ':TYPE': 'wdo#antonym'}
# 00244146-a
# {':START_ID': '00394166-a', ':END_ID': '00393873-a', ':TYPE': 'wdo#antonym'}
# 00394166-a
# {':START_ID': '04587272-n', ':END_ID': '02849498-n', ':TYPE': 'wdo#antonym'}
# 04587272-n
# {':START_ID': '04967906-n', ':END_ID': '04967454-n', ':TYPE': 'wdo#antonym'}
# 04967906-n
# {':START_ID': '02566724-a', ':END_ID': '02567490-a', ':TYPE': 'wdo#antonym'}
# 02566724-a
# {':START_ID': '00281071-v', ':END_ID': '00281302-v', ':TYPE': 'wdo#antonym'}
# 00281071-v
# {':START_ID': '00516809-a', ':END_ID': '00518464-a', ':TYPE': 'wdo#antonym'}
# 00516809-a
# {':START_ID': '00519841-a', ':END_ID': '00519960-a', ':TYPE': 'wdo#antonym'}
# 00519841-a
# {':START_ID': '07862778-n', ':END_ID': '07862533-n', ':TYPE': 'wdo#antonym'}
# 07862778-n
# {':START_ID': '00444667-r', ':END_ID': '00444562-r', ':TYPE': 'wdo#antonym'}
# 00444667-r
# {':START_ID': '01116756-n', ':END_ID': '01116568-n', ':TYPE': 'wdo#antonym'}
# 01116756-n
# {':START_ID': '02252008-v', ':END_ID': '02251810-v', ':TYPE': 'wdo#antonym'}
# 02252008-v
# {':START_ID': '02568127-a', ':END_ID': '02569950-a', ':TYPE': 'wdo#antonym'}
# 02568127-a
# {':START_ID': '04796917-n', ':END_ID': '04797677-n', ':TYPE': 'wdo#antonym'}
# 04796917-n
# {':START_ID': '00008423-r', ':END_ID': '00008102-r', ':TYPE': 'wdo#antonym'}
# 00008423-r
# {':START_ID': '02523798-a', ':END_ID': '02523327-a', ':TYPE': 'wdo#antonym'}
# 02523798-a
# {':START_ID': '02571278-a', ':END_ID': '02572618-a', ':TYPE': 'wdo#antonym'}
# 02571278-a
# {':START_ID': '02573798-a', ':END_ID': '02574040-a', ':TYPE': 'wdo#antonym'}
# 02573798-a
# {':START_ID': '00304246-v', ':END_ID': '00305890-v', ':TYPE': 'wdo#antonym'}
# 00304246-v
# {':START_ID': '05143608-n', ':END_ID': '05144053-n', ':TYPE': 'wdo#antonym'}
# 05143608-n
# {':START_ID': '00408091-n', ':END_ID': '00408228-n', ':TYPE': 'wdo#antonym'}
# 00408091-n
# {':START_ID': '13596007-n', ':END_ID': '13539766-n', ':TYPE': 'wdo#antonym'}
# 13596007-n
# {':START_ID': '02574346-a', ':END_ID': '02574457-a', ':TYPE': 'wdo#antonym'}
# 02574346-a
# {':START_ID': '10800308-n', ':END_ID': '10213586-n', ':TYPE': 'wdo#antonym'}
# 10800308-n
# {':START_ID': '01739724-a', ':END_ID': '01739871-a', ':TYPE': 'wdo#antonym'}
# 01739724-a
# {':START_ID': '02575276-a', ':END_ID': '02575645-a', ':TYPE': 'wdo#antonym'}
# 02575276-a
# {':START_ID': '02575645-a', ':END_ID': '02575276-a', ':TYPE': 'wdo#antonym'}
# 02575645-a
# {':START_ID': '02397788-a', ':END_ID': '02396713-a', ':TYPE': 'wdo#antonym'}
# 02397788-a
# {':START_ID': '02398903-a', ':END_ID': '02398514-a', ':TYPE': 'wdo#antonym'}
# 02398903-a
# {':START_ID': '04915003-n', ':END_ID': '04913019-n', ':TYPE': 'wdo#antonym'}
# 04915003-n
# {':START_ID': '02575716-a', ':END_ID': '02576745-a', ':TYPE': 'wdo#antonym'}
# 02575716-a
# {':START_ID': '00306669-r', ':END_ID': '00306817-r', ':TYPE': 'wdo#antonym'}
# 00306669-r
# {':START_ID': '04651869-n', ':END_ID': '04652956-n', ':TYPE': 'wdo#antonym'}
# 04651869-n
# {':START_ID': '01102556-v', ':END_ID': '01102003-v', ':TYPE': 'wdo#antonym'}
# 01102556-v
# {':START_ID': '02293158-v', ':END_ID': '02293000-v', ':TYPE': 'wdo#antonym'}
# 02293158-v
# {':START_ID': '01525056-v', ':END_ID': '01526442-v', ':TYPE': 'wdo#antonym'}
# 01525056-v
# {':START_ID': '00095613-r', ':END_ID': '00095742-r', ':TYPE': 'wdo#antonym'}
# 00095613-r
# {':START_ID': '01403340-a', ':END_ID': '01403102-a', ':TYPE': 'wdo#antonym'}
# 01403340-a
# {':START_ID': '08627580-n', ':END_ID': '08609908-n', ':TYPE': 'wdo#antonym'}
# 08627580-n
# {':START_ID': '13851799-n', ':END_ID': '13852047-n', ':TYPE': 'wdo#antonym'}
# 13851799-n
# {':START_ID': '02577356-a', ':END_ID': '02578841-a', ':TYPE': 'wdo#antonym'}
# 02577356-a
# {':START_ID': '02578841-a', ':END_ID': '02577356-a', ':TYPE': 'wdo#antonym'}
# 02578841-a
# {':START_ID': '10802467-n', ':END_ID': '10292479-n', ':TYPE': 'wdo#antonym'}
# 10802467-n
# {':START_ID': '10802616-n', ':END_ID': '10292610-n', ':TYPE': 'wdo#antonym'}
# 10802616-n
# {':START_ID': '13280816-n', ':END_ID': '13350344-n', ':TYPE': 'wdo#antonym'}
# 13280816-n
# {':START_ID': '15247986-n', ':END_ID': '15246808-n', ':TYPE': 'wdo#antonym'}
# 15247986-n
# {':START_ID': '00409197-v', ':END_ID': '00409373-v', ':TYPE': 'wdo#antonym'}
# 00409197-v
# {':START_ID': '01258879-a', ':END_ID': '01258368-a', ':TYPE': 'wdo#antonym'}
# 01258879-a
# {':START_ID': '01258879-a', ':END_ID': '01257856-a', ':TYPE': 'wdo#antonym'}
# 01258879-a
# {':START_ID': '01258879-a', ':END_ID': '01257504-a', ':TYPE': 'wdo#antonym'}
# 01258879-a
# {':START_ID': '01601973-v', ':END_ID': '01602146-v', ':TYPE': 'wdo#antonym'}
# 01601973-v
# {':START_ID': '02579112-a', ':END_ID': '02579586-a', ':TYPE': 'wdo#antonym'}
# 02579112-a
# {':START_ID': '02579586-a', ':END_ID': '02579112-a', ':TYPE': 'wdo#antonym'}
# 02579586-a
# {':START_ID': '04897307-n', ':END_ID': '04898528-n', ':TYPE': 'wdo#antonym'}
# 04897307-n
# {':START_ID': '02579686-a', ':END_ID': '02580838-a', ':TYPE': 'wdo#antonym'}
# 02579686-a
# {':START_ID': '00202999-r', ':END_ID': '00203162-r', ':TYPE': 'wdo#antonym'}
# 00202999-r
# {':START_ID': '01828474-v', ':END_ID': '01829067-v', ':TYPE': 'wdo#antonym'}
# 01828474-v
# {':START_ID': '02316367-v', ':END_ID': '02315835-v', ':TYPE': 'wdo#antonym'}
# 02316367-v
# {':START_ID': '10805371-n', ':END_ID': '10163245-n', ':TYPE': 'wdo#antonym'}
# 10805371-n
# {':START_ID': '00194357-a', ':END_ID': '00194481-a', ':TYPE': 'wdo#antonym'}
# 00194357-a
# {':START_ID': '00239363-r', ':END_ID': '00239560-r', ':TYPE': 'wdo#antonym'}
# 00239363-r
# {':START_ID': '10807146-n', ':END_ID': '10306910-n', ':TYPE': 'wdo#antonym'}
# 10807146-n
# {':START_ID': '10808492-n', ':END_ID': '10308177-n', ':TYPE': 'wdo#antonym'}
# 10808492-n
# {':START_ID': '01488294-a', ':END_ID': '01488809-a', ':TYPE': 'wdo#antonym'}
# 01488294-a
# {':START_ID': '01455267-a', ':END_ID': '01455045-a', ':TYPE': 'wdo#antonym'}
# 01455267-a
# {':START_ID': '02583261-a', ':END_ID': '02585446-a', ':TYPE': 'wdo#antonym'}
# 02583261-a
# {':START_ID': '02585768-a', ':END_ID': '02587095-a', ':TYPE': 'wdo#antonym'}
# 02585768-a
# {':START_ID': '02418610-v', ':END_ID': '02422604-v', ':TYPE': 'wdo#antonym'}
# 02418610-v
# {':START_ID': '15143170-n', ':END_ID': '15143395-n', ':TYPE': 'wdo#antonym'}
# 15143170-n
# {':START_ID': '15161875-n', ':END_ID': '15161999-n', ':TYPE': 'wdo#antonym'}
# 15161875-n
# {':START_ID': '09655706-n', ':END_ID': '09649219-n', ':TYPE': 'wdo#antonym'}
# 09655706-n
# {':START_ID': '04628881-n', ':END_ID': '04628671-n', ':TYPE': 'wdo#antonym'}
# 04628881-n
# {':START_ID': '02587499-a', ':END_ID': '02588673-a', ':TYPE': 'wdo#antonym'}
# 02587499-a
# {':START_ID': '02590887-a', ':END_ID': '02595137-a', ':TYPE': 'wdo#antonym'}
# 02590887-a
# {':START_ID': '01769760-v', ':END_ID': '01770259-v', ':TYPE': 'wdo#antonym'}
# 01769760-v
# {':START_ID': '00232844-a', ':END_ID': '00231927-a', ':TYPE': 'wdo#antonym'}
# 00232844-a
# {':START_ID': '00233660-a', ':END_ID': '00233353-a', ':TYPE': 'wdo#antonym'}
# 00233660-a
# {':START_ID': '00204228-v', ':END_ID': '00205454-v', ':TYPE': 'wdo#antonym'}
# 00204228-v
# {':START_ID': '00208618-v', ':END_ID': '00206293-v', ':TYPE': 'wdo#antonym'}
# 00208618-v
# {':START_ID': '00234743-a', ':END_ID': '00233826-a', ':TYPE': 'wdo#antonym'}
# 00234743-a
# {':START_ID': '00128492-n', ':END_ID': '00128351-n', ':TYPE': 'wdo#antonym'}
# 00128492-n
# {':START_ID': '00231222-a', ':END_ID': '00229099-a', ':TYPE': 'wdo#antonym'}
# 00231222-a
# {':START_ID': '05145473-n', ':END_ID': '05146826-n', ':TYPE': 'wdo#antonym'}
# 05145473-n
# {':START_ID': '04813883-n', ':END_ID': '04815028-n', ':TYPE': 'wdo#antonym'}
# 04813883-n
# {':START_ID': '02512179-a', ':END_ID': '02510833-a', ':TYPE': 'wdo#antonym'}
# 02512179-a
# {':START_ID': '05146826-n', ':END_ID': '05145473-n', ':TYPE': 'wdo#antonym'}
# 05146826-n
# {':START_ID': '02595419-a', ':END_ID': '02598414-a', ':TYPE': 'wdo#antonym'}
# 02595419-a
# {':START_ID': '02589907-a', ':END_ID': '02590390-a', ':TYPE': 'wdo#antonym'}
# 02589907-a
# {':START_ID': '01285811-v', ':END_ID': '01286874-v', ':TYPE': 'wdo#antonym'}
# 01285811-v
# {':START_ID': '02094739-a', ':END_ID': '02094868-a', ':TYPE': 'wdo#antonym'}
# 02094739-a
# {':START_ID': '01363329-a', ':END_ID': '01363608-a', ':TYPE': 'wdo#antonym'}
# 01363329-a
# {':START_ID': '02292312-a', ':END_ID': '02291437-a', ':TYPE': 'wdo#antonym'}
# 02292312-a
# {':START_ID': '02294393-a', ':END_ID': '02294659-a', ':TYPE': 'wdo#antonym'}
# 02294393-a
# {':START_ID': '00635278-a', ':END_ID': '00634232-a', ':TYPE': 'wdo#antonym'}
# 00635278-a
# {':START_ID': '00636618-a', ':END_ID': '00636250-a', ':TYPE': 'wdo#antonym'}
# 00636618-a
# {':START_ID': '02042744-a', ':END_ID': '02042235-a', ':TYPE': 'wdo#antonym'}
# 02042744-a
# {':START_ID': '02519655-v', ':END_ID': '02525657-v', ':TYPE': 'wdo#antonym'}
# 02519655-v
# {':START_ID': '04861835-n', ':END_ID': '04857572-n', ':TYPE': 'wdo#antonym'}
# 04861835-n
# {':START_ID': '04861835-n', ':END_ID': '04857572-n', ':TYPE': 'wdo#antonym'}
# 04861835-n
# {':START_ID': '00205553-r', ':END_ID': '00205350-r', ':TYPE': 'wdo#antonym'}
# 00205553-r
# {':START_ID': '04809652-n', ':END_ID': '04809447-n', ':TYPE': 'wdo#antonym'}
# 04809652-n
# {':START_ID': '04859193-n', ':END_ID': '04854364-n', ':TYPE': 'wdo#antonym'}
# 04859193-n
# {':START_ID': '02606374-a', ':END_ID': '02606144-a', ':TYPE': 'wdo#antonym'}
# 02606374-a
# {':START_ID': '02599077-a', ':END_ID': '02599401-a', ':TYPE': 'wdo#antonym'}
# 02599077-a
# {':START_ID': '02599077-a', ':END_ID': '02599866-a', ':TYPE': 'wdo#antonym'}
# 02599077-a
# {':START_ID': '05923950-n', ':END_ID': '05924178-n', ':TYPE': 'wdo#antonym'}
# 05923950-n
# {':START_ID': '07218668-n', ':END_ID': '07219870-n', ':TYPE': 'wdo#antonym'}
# 07218668-n
# {':START_ID': '01497577-a', ':END_ID': '01497421-a', ':TYPE': 'wdo#antonym'}
# 01497577-a
# {':START_ID': '07218560-n', ':END_ID': '07219764-n', ':TYPE': 'wdo#antonym'}
# 07218560-n
# {':START_ID': '02709149-v', ':END_ID': '02707980-v', ':TYPE': 'wdo#antonym'}
# 02709149-v
# {':START_ID': '05924178-n', ':END_ID': '05923950-n', ':TYPE': 'wdo#antonym'}
# 05924178-n
# {':START_ID': '01493615-v', ':END_ID': '01494017-v', ':TYPE': 'wdo#antonym'}
# 01493615-v
# {':START_ID': '01651383-a', ':END_ID': '01648062-a', ':TYPE': 'wdo#antonym'}
# 01651383-a
# {':START_ID': '07960326-n', ':END_ID': '07960146-n', ':TYPE': 'wdo#antonym'}
# 07960326-n
# {':START_ID': '04935593-n', ':END_ID': '04934622-n', ':TYPE': 'wdo#antonym'}
# 04935593-n
# {':START_ID': '08702507-n', ':END_ID': '08618316-n', ':TYPE': 'wdo#antonym'}
# 08702507-n
# {':START_ID': '01356373-v', ':END_ID': '01344906-v', ':TYPE': 'wdo#antonym'}
# 01356373-v
# {':START_ID': '02600228-a', ':END_ID': '02600372-a', ':TYPE': 'wdo#antonym'}
# 02600228-a
# {':START_ID': '01202129-a', ':END_ID': '01201976-a', ':TYPE': 'wdo#antonym'}
# 01202129-a
# {':START_ID': '02157476-n', ':END_ID': '02157666-n', ':TYPE': 'wdo#antonym'}
# 02157476-n
# {':START_ID': '02383265-a', ':END_ID': '02382917-a', ':TYPE': 'wdo#antonym'}
# 02383265-a
# done.
# csv_imports/WN-log.log
# #### Log file written in  None
# done.

# %% [markdown]
# ### Sample RDF Querying

# %%
import requests 

id="00001740-n"
response = requests.get("http://wordnet-rdf.princeton.edu/json/id/"+id)
data = response.json()
dic = data[0]
defn = dic['definition']
lemmas = dic['lemmas']
word = (lemmas[0])['lemma']
subject = dic['subject']
pos = dic['pos']
lang = (lemmas[0])['language']
print(word,':',defn,':',pos,':',subject,':',lang)
# Out:
# entity : that which is perceived or known or inferred to have its own distinct existence (living or nonliving) : n : noun.Tops : en
