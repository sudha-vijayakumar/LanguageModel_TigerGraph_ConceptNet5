# %%
#Reference:
#https://github.com/tomkdickinson/wordnet_conceptnet_neo4j

import nltk
import nltk.corpus
import csv
import json
import logging as log
import gzip
import math
import os
import re

log.basicConfig(level=log.INFO)


class WordNode:
    def __init__(self, id, name, pos, is_lemma=False, is_concept=False, concept_uri=None):
        self._id = id
        self._name = name
        self._pos = pos
        self._concept_uri = concept_uri
        self._is_lemma = is_lemma
        self._is_concept = is_concept
        if not is_lemma and not is_concept:
            raise Exception('WordNode must be at least either a lemma or a concept')

    @staticmethod
    def get_header():
        return ['id:ID', 'name', 'pos', 'conceptUri', ':LABEL']

    def get_row(self):
        labels = []
        if self._is_lemma:
            labels.append('Lemma')
        if self._is_concept:
            labels.append('Concept')
        return [self._id, self._name, self._pos, self._concept_uri, ';'.join(labels)]

    @property
    def get_id(self):
        return self._id

    def set_is_concept(self):
        self._is_concept = True

    @property
    def get_concept_uri(self):
        return self._concept_uri

    def set_concept_uri(self, concept_uri):
        self._concept_uri = concept_uri


class SynsetNode:
    def __init__(self, id, pos, definition):
        self._label = 'Synset'
        self._id = id
        self._pos = pos
        self._definition = definition

    @property
    def get_id(self):
        return self._id

    @property
    def get_pos(self):
        return self._pos

    @property
    def get_definition(self):
        return self._definition

    @property
    def get_label(self):
        return self._label


class Exporter:
    """
    This class exports WordNet into a csv file for ingestion into Neo4J
    """

    def __init__(self, dataset_folder, concept_location=None, language_filter=None):
        self.dataset_folder = dataset_folder
        os.makedirs(self.dataset_folder, exist_ok=True)
        self.relationships = []
        self.relationship_index = {}
        self.words = []
        self.synsets = []
        self.lemma_map = {}
        self.concept_location = concept_location
        self.language_filter = language_filter

    def export(self):
        self.extract_wordnet()
        if self.concept_location is not None:
            self.extract_conceptnet()
        self.write_results()

    def extract_wordnet(self):
        """
        Extracts wordnet
        :return:
        """
        log.info('Extracting WordNet')
        all_synsets = list(nltk.corpus.wordnet.all_synsets())
        last_progress = 0
        for i, synset in enumerate(all_synsets):
            self.synsets.append(SynsetNode(synset.name(), synset.pos(), synset.definition()))
            self.extract_relationships(synset)
            self.extract_lemmas(synset)
            progress = math.floor((i / len(all_synsets) * 100))
            if progress > last_progress:
                last_progress = progress
                log.info("%f%% Synsets extracted" % progress)

    def extract_conceptnet(self):
        log.info('Extracting ConceptNet')
        last_progress = 0
        with gzip.open(self.concept_location, 'rt') as f:
            lines = csv.reader(f, delimiter='\t')
            i = 0
            for line in lines:
                start = self.extract_concept(line[2])
                end = self.extract_concept(line[3])
                if start is not None and end is not None:
                    self.add_concept_node(start)
                    self.add_concept_node(end)
                    dataset, weight = self.extract_edge_details(line[4])
                    self.add_relationship(start.get_id, end.get_id, re.sub('/r/', '', line[1]), dataset, weight)

                i += 1
                progress_round = 10000
                progress = math.floor(i / progress_round) * progress_round
                if progress > last_progress:
                    last_progress = progress
                    log.info('Extracted %i concept assertions' % progress)

    def extract_edge_details(self, edge_string):
        try:
            dataset = None
            weight = None
            edge = json.loads(edge_string)
            if 'dataset' in edge:
                dataset = edge['dataset']
            if 'weight' in edge:
                try:
                    weight = float(edge['weight'])
                except Exception as e:
                    log.error(e)
            return dataset, weight
        except Exception as e:
            log.error(e)
            return None, None

    def add_concept_node(self, concept):
        if concept is not None:
            if concept.get_id in self.lemma_map:
                self.lemma_map[concept.get_id.lower()].set_is_concept()
            else:
                self.lemma_map[concept.get_id.lower()] = concept
            self.lemma_map[concept.get_id.lower()].set_concept_uri(concept.get_concept_uri)

    def extract_concept(self, concept_uri):
        concept_parts = concept_uri[1:].split('/')
        if self.language_filter is None or concept_parts[1] == self.language_filter:
            if len(concept_parts) > 3:
                return WordNode(id='%s.%s' % (concept_parts[2], concept_parts[3]), pos=concept_parts[3],
                                name=concept_parts[2], concept_uri=concept_uri, is_concept=True)
            else:
                return WordNode(id=concept_parts[2], pos=None, name=concept_parts[2], concept_uri=concept_uri,
                                is_concept=True)
        return None

    def extract_relationships(self, synset):
        # Hyponyms - Child
        for related_node in synset.hyponyms():
            self.add_relationship(related_node.name(), synset.name(), 'IsA', weight=2, dataset="/d/wordnet/3.1")

        # Hypernyms - Parent
        for related_node in synset.hypernyms():
            self.add_relationship(synset.name(), related_node.name(), 'IsA', weight=2, dataset="/d/wordnet/3.1")

        # Holonyms

        # Member Holonyms
        for related_node in synset.member_holonyms():
            self.add_relationship(synset.name(), related_node.name(), 'PartOf', weight=2, dataset="/d/wordnet/3.1")

        # substance_holonyms
        for related_node in synset.substance_holonyms():
            self.add_relationship(synset.name(), related_node.name(), 'PartOf', weight=2, dataset="/d/wordnet/3.1")

        # part_holonyms
        for related_node in synset.part_holonyms():
            self.add_relationship(synset.name(), related_node.name(), 'PartOf', weight=2, dataset="/d/wordnet/3.1")

        # Meronyms Child

        # Member meronyms
        for related_node in synset.member_meronyms():
            self.add_relationship(related_node.name(), synset.name(), 'PartOf', weight=2, dataset="/d/wordnet/3.1")

        # substance_meronyms
        for related_node in synset.substance_meronyms():
            self.add_relationship(related_node.name(), synset.name(), 'PartOf', weight=2, dataset="/d/wordnet/3.1")

        # part_meronyms
        for related_node in synset.part_meronyms():
            self.add_relationship(related_node.name(), synset.name(), 'PartOf', weight=2, dataset="/d/wordnet/3.1")

        # Domains

        # topic_domains
        for related_node in synset.topic_domains():
            self.add_relationship(synset.name(), related_node.name(), 'Domain', weight=2, dataset="/d/wordnet/3.1")

        # region_domains
        for related_node in synset.region_domains():
            self.add_relationship(synset.name(), related_node.name(), 'Domain', weight=2, dataset="/d/wordnet/3.1")

        # usage_domains
        for related_node in synset.usage_domains():
            self.add_relationship(synset.name(), related_node.name(), 'Domain', weight=2, dataset="/d/wordnet/3.1")

        # attributes
        for related_node in synset.attributes():
            self.add_relationship(synset.name(), related_node.name(), 'Attribute', weight=2, dataset="/d/wordnet/3.1")
        # entailments
        for related_node in synset.entailments():
            self.add_relationship(synset.name(), related_node.name(), 'Entailment', weight=2, dataset="/d/wordnet/3.1")
        # causes
        for related_node in synset.causes():
            self.add_relationship(synset.name(), related_node.name(), 'Cause', weight=2, dataset="/d/wordnet/3.1")
        # also_sees
        for related_node in synset.also_sees():
            self.add_relationship(synset.name(), related_node.name(), 'AlsoSee', weight=2, dataset="/d/wordnet/3.1")
        # verb_groups
        for related_node in synset.verb_groups():
            self.add_relationship(synset.name(), related_node.name(), 'VerbGroup', weight=2, dataset="/d/wordnet/3.1")
        # similar_tos
        for related_node in synset.similar_tos():
            self.add_relationship(synset.name(), related_node.name(), 'SimilarTo', weight=2, dataset="/d/wordnet/3.1")

    def extract_lemmas(self, synset):
        for lemma in synset.lemmas():
            id = ('%s.%s' % (lemma.name().lower(), synset.pos())).lower()
            if id not in self.lemma_map:
                self.lemma_map[id] = WordNode(id, lemma.name().lower(), synset.pos(), is_lemma=True)
            self.add_relationship(id, synset.name(), 'InSynset', weight=2, dataset="/d/wordnet/3.1")

    def index_relationship(self, start, end, rel_type):
        self.relationship_index.setdefault(start, {})
        self.relationship_index[start].setdefault(end, [])
        self.relationship_index[start][end].append(rel_type)

    def add_relationship(self, start, end, rel_type, dataset=None, weight=None):
        """
        Checks and adds only bi-directional relationships
        :param start:
        :param end:
        :param rel_type:
        :param dataset:
        :param weight:
        :return:
        """
        if (start in self.relationship_index and end in self.relationship_index[start] and rel_type in
            self.relationship_index[start][end]) or \
                (end in self.relationship_index and start in self.relationship_index[end] and rel_type in
                 self.relationship_index[end][start]):
            pass
        else:
            self.index_relationship(start, end, rel_type)
            self.index_relationship(end, start, rel_type)
            self.relationships.append([start, end, dataset, weight, rel_type])

    def write_results(self):
        log.info("Writing synsets")
        with open('%s/synsets.csv' % self.dataset_folder, 'w', encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(['id:ID', 'pos:string', 'definition:string', ':LABEL'])
            for synset in self.synsets:
                writer.writerow([synset.get_id, synset.get_pos, synset.get_definition, synset.get_label])

        log.info('Writing Relationships')
        with open('%s/relationships.csv' % self.dataset_folder, 'w', encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([':START_ID', ':END_ID', 'dataset:string', 'weight:double', ':TYPE'])
            for relationship in self.relationships:
                writer.writerow(relationship)

        log.info('Writing Words')
        with open('%s/words.csv' % self.dataset_folder, 'w', encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(WordNode.get_header())
            for id in self.lemma_map:
                writer.writerow(self.lemma_map[id].get_row())


if __name__ == '__main__':
    nltk.download('wordnet')
    Exporter('csv_imports', 'conceptnet-assertions.csv.gz', language_filter='en').export()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sudha.vijayakumar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# INFO:root:Extracting WordNet
# INFO:root:1.000000% Synsets extracted
# INFO:root:2.000000% Synsets extracted
# INFO:root:3.000000% Synsets extracted
# INFO:root:4.000000% Synsets extracted
# INFO:root:5.000000% Synsets extracted
# INFO:root:6.000000% Synsets extracted
# INFO:root:7.000000% Synsets extracted
# INFO:root:8.000000% Synsets extracted
# INFO:root:9.000000% Synsets extracted
# INFO:root:10.000000% Synsets extracted
# INFO:root:11.000000% Synsets extracted
# INFO:root:12.000000% Synsets extracted
# INFO:root:13.000000% Synsets extracted
# INFO:root:14.000000% Synsets extracted
# INFO:root:15.000000% Synsets extracted
# INFO:root:16.000000% Synsets extracted
# INFO:root:17.000000% Synsets extracted
# INFO:root:18.000000% Synsets extracted
# INFO:root:19.000000% Synsets extracted
# INFO:root:20.000000% Synsets extracted
# INFO:root:21.000000% Synsets extracted
# INFO:root:22.000000% Synsets extracted
# INFO:root:23.000000% Synsets extracted
# INFO:root:24.000000% Synsets extracted
# INFO:root:25.000000% Synsets extracted
# INFO:root:26.000000% Synsets extracted
# INFO:root:27.000000% Synsets extracted
# INFO:root:28.000000% Synsets extracted
# INFO:root:29.000000% Synsets extracted
# INFO:root:30.000000% Synsets extracted
# INFO:root:31.000000% Synsets extracted
# INFO:root:32.000000% Synsets extracted
# INFO:root:33.000000% Synsets extracted
# INFO:root:34.000000% Synsets extracted
# INFO:root:35.000000% Synsets extracted
# INFO:root:36.000000% Synsets extracted
# INFO:root:37.000000% Synsets extracted
# INFO:root:38.000000% Synsets extracted
# INFO:root:39.000000% Synsets extracted
# INFO:root:40.000000% Synsets extracted
# INFO:root:41.000000% Synsets extracted
# INFO:root:42.000000% Synsets extracted
# INFO:root:43.000000% Synsets extracted
# INFO:root:44.000000% Synsets extracted
# INFO:root:45.000000% Synsets extracted
# INFO:root:46.000000% Synsets extracted
# INFO:root:47.000000% Synsets extracted
# INFO:root:48.000000% Synsets extracted
# INFO:root:49.000000% Synsets extracted
# INFO:root:50.000000% Synsets extracted
# INFO:root:51.000000% Synsets extracted
# INFO:root:52.000000% Synsets extracted
# INFO:root:53.000000% Synsets extracted
# INFO:root:54.000000% Synsets extracted
# INFO:root:55.000000% Synsets extracted
# INFO:root:56.000000% Synsets extracted
# INFO:root:57.000000% Synsets extracted
# INFO:root:58.000000% Synsets extracted
# INFO:root:59.000000% Synsets extracted
# INFO:root:60.000000% Synsets extracted
# INFO:root:61.000000% Synsets extracted
# INFO:root:62.000000% Synsets extracted
# INFO:root:63.000000% Synsets extracted
# INFO:root:64.000000% Synsets extracted
# INFO:root:65.000000% Synsets extracted
# INFO:root:66.000000% Synsets extracted
# INFO:root:67.000000% Synsets extracted
# INFO:root:68.000000% Synsets extracted
# INFO:root:69.000000% Synsets extracted
# INFO:root:70.000000% Synsets extracted
# INFO:root:71.000000% Synsets extracted
# INFO:root:72.000000% Synsets extracted
# INFO:root:73.000000% Synsets extracted
# INFO:root:74.000000% Synsets extracted
# INFO:root:75.000000% Synsets extracted
# INFO:root:76.000000% Synsets extracted
# INFO:root:77.000000% Synsets extracted
# INFO:root:78.000000% Synsets extracted
# INFO:root:79.000000% Synsets extracted
# INFO:root:80.000000% Synsets extracted
# INFO:root:81.000000% Synsets extracted
# INFO:root:82.000000% Synsets extracted
# INFO:root:83.000000% Synsets extracted
# INFO:root:84.000000% Synsets extracted
# INFO:root:85.000000% Synsets extracted
# INFO:root:86.000000% Synsets extracted
# INFO:root:87.000000% Synsets extracted
# INFO:root:88.000000% Synsets extracted
# INFO:root:89.000000% Synsets extracted
# INFO:root:90.000000% Synsets extracted
# INFO:root:91.000000% Synsets extracted
# INFO:root:92.000000% Synsets extracted
# INFO:root:93.000000% Synsets extracted
# INFO:root:94.000000% Synsets extracted
# INFO:root:95.000000% Synsets extracted
# INFO:root:96.000000% Synsets extracted
# INFO:root:97.000000% Synsets extracted
# INFO:root:98.000000% Synsets extracted
# INFO:root:99.000000% Synsets extracted
# INFO:root:Extracting ConceptNet
# INFO:root:Extracted 10000 concept assertions
# INFO:root:Extracted 20000 concept assertions
# INFO:root:Extracted 30000 concept assertions
# INFO:root:Extracted 40000 concept assertions
# INFO:root:Extracted 50000 concept assertions
# INFO:root:Extracted 60000 concept assertions
# INFO:root:Extracted 70000 concept assertions
# INFO:root:Extracted 80000 concept assertions
# INFO:root:Extracted 90000 concept assertions
# INFO:root:Extracted 100000 concept assertions
# INFO:root:Extracted 110000 concept assertions
# INFO:root:Extracted 120000 concept assertions
# INFO:root:Extracted 130000 concept assertions
# INFO:root:Extracted 140000 concept assertions
# INFO:root:Extracted 150000 concept assertions
# INFO:root:Extracted 160000 concept assertions
# INFO:root:Extracted 170000 concept assertions
# INFO:root:Extracted 180000 concept assertions
# INFO:root:Extracted 190000 concept assertions
# INFO:root:Extracted 200000 concept assertions
# INFO:root:Extracted 210000 concept assertions
# INFO:root:Extracted 220000 concept assertions
# INFO:root:Extracted 230000 concept assertions
# INFO:root:Extracted 240000 concept assertions
# INFO:root:Extracted 250000 concept assertions
# INFO:root:Extracted 260000 concept assertions
# INFO:root:Extracted 270000 concept assertions
# INFO:root:Extracted 280000 concept assertions
# INFO:root:Extracted 290000 concept assertions
# INFO:root:Extracted 300000 concept assertions
# INFO:root:Extracted 310000 concept assertions
# INFO:root:Extracted 320000 concept assertions
# INFO:root:Extracted 330000 concept assertions
# INFO:root:Extracted 340000 concept assertions
# INFO:root:Extracted 350000 concept assertions
# INFO:root:Extracted 360000 concept assertions
# INFO:root:Extracted 370000 concept assertions
# INFO:root:Extracted 380000 concept assertions
# INFO:root:Extracted 390000 concept assertions
# INFO:root:Extracted 400000 concept assertions
# INFO:root:Extracted 410000 concept assertions
# INFO:root:Extracted 420000 concept assertions
# INFO:root:Extracted 430000 concept assertions
# INFO:root:Extracted 440000 concept assertions
# INFO:root:Extracted 450000 concept assertions
# INFO:root:Extracted 460000 concept assertions
# INFO:root:Extracted 470000 concept assertions
# INFO:root:Extracted 480000 concept assertions
# INFO:root:Extracted 490000 concept assertions
# INFO:root:Extracted 500000 concept assertions
# INFO:root:Extracted 510000 concept assertions
# INFO:root:Extracted 520000 concept assertions
# INFO:root:Extracted 530000 concept assertions
# INFO:root:Extracted 540000 concept assertions
# INFO:root:Extracted 550000 concept assertions
# INFO:root:Extracted 560000 concept assertions
# INFO:root:Extracted 570000 concept assertions
# INFO:root:Extracted 580000 concept assertions
# INFO:root:Extracted 590000 concept assertions
# INFO:root:Extracted 600000 concept assertions
# INFO:root:Extracted 610000 concept assertions
# INFO:root:Extracted 620000 concept assertions
# INFO:root:Extracted 630000 concept assertions
# INFO:root:Extracted 640000 concept assertions
# INFO:root:Extracted 650000 concept assertions
# INFO:root:Extracted 660000 concept assertions
# INFO:root:Extracted 670000 concept assertions
# INFO:root:Extracted 680000 concept assertions
# INFO:root:Extracted 690000 concept assertions
# INFO:root:Extracted 700000 concept assertions
# INFO:root:Extracted 710000 concept assertions
# INFO:root:Extracted 720000 concept assertions
# INFO:root:Extracted 730000 concept assertions
# INFO:root:Extracted 740000 concept assertions
# INFO:root:Extracted 750000 concept assertions
# INFO:root:Extracted 760000 concept assertions
# INFO:root:Extracted 770000 concept assertions
# INFO:root:Extracted 780000 concept assertions
# INFO:root:Extracted 790000 concept assertions
# INFO:root:Extracted 800000 concept assertions
# INFO:root:Extracted 810000 concept assertions
# INFO:root:Extracted 820000 concept assertions
# INFO:root:Extracted 830000 concept assertions
# INFO:root:Extracted 840000 concept assertions
# INFO:root:Extracted 850000 concept assertions
# INFO:root:Extracted 860000 concept assertions
# INFO:root:Extracted 870000 concept assertions
# INFO:root:Extracted 880000 concept assertions
# INFO:root:Extracted 890000 concept assertions
# INFO:root:Extracted 900000 concept assertions
# INFO:root:Extracted 910000 concept assertions
# INFO:root:Extracted 920000 concept assertions
# INFO:root:Extracted 930000 concept assertions
# INFO:root:Extracted 940000 concept assertions
# INFO:root:Extracted 950000 concept assertions
# INFO:root:Extracted 960000 concept assertions
# INFO:root:Extracted 970000 concept assertions
# INFO:root:Extracted 980000 concept assertions
# INFO:root:Extracted 990000 concept assertions
# INFO:root:Extracted 1000000 concept assertions
# INFO:root:Extracted 1010000 concept assertions
# INFO:root:Extracted 1020000 concept assertions
# INFO:root:Extracted 1030000 concept assertions
# INFO:root:Extracted 1040000 concept assertions
# INFO:root:Extracted 1050000 concept assertions
# INFO:root:Extracted 1060000 concept assertions
# INFO:root:Extracted 1070000 concept assertions
# INFO:root:Extracted 1080000 concept assertions
# INFO:root:Extracted 1090000 concept assertions
# INFO:root:Extracted 1100000 concept assertions
# INFO:root:Extracted 1110000 concept assertions
# INFO:root:Extracted 1120000 concept assertions
# INFO:root:Extracted 1130000 concept assertions
# INFO:root:Extracted 1140000 concept assertions
# INFO:root:Extracted 1150000 concept assertions
# INFO:root:Extracted 1160000 concept assertions
# INFO:root:Extracted 1170000 concept assertions
# INFO:root:Extracted 1180000 concept assertions
# INFO:root:Extracted 1190000 concept assertions
# INFO:root:Extracted 1200000 concept assertions
# INFO:root:Extracted 1210000 concept assertions
# INFO:root:Extracted 1220000 concept assertions
# INFO:root:Extracted 1230000 concept assertions
# INFO:root:Extracted 1240000 concept assertions
# INFO:root:Extracted 1250000 concept assertions
# INFO:root:Extracted 1260000 concept assertions
# INFO:root:Extracted 1270000 concept assertions
# INFO:root:Extracted 1280000 concept assertions
# INFO:root:Extracted 1290000 concept assertions
# INFO:root:Extracted 1300000 concept assertions
# INFO:root:Extracted 1310000 concept assertions
# INFO:root:Extracted 1320000 concept assertions
# INFO:root:Extracted 1330000 concept assertions
# INFO:root:Extracted 1340000 concept assertions
# INFO:root:Extracted 1350000 concept assertions
# INFO:root:Extracted 1360000 concept assertions
# INFO:root:Extracted 1370000 concept assertions
# INFO:root:Extracted 1380000 concept assertions
# INFO:root:Extracted 1390000 concept assertions
# INFO:root:Extracted 1400000 concept assertions
# INFO:root:Extracted 1410000 concept assertions
# INFO:root:Extracted 1420000 concept assertions
# INFO:root:Extracted 1430000 concept assertions
# INFO:root:Extracted 1440000 concept assertions
# INFO:root:Extracted 1450000 concept assertions
# INFO:root:Extracted 1460000 concept assertions
# INFO:root:Extracted 1470000 concept assertions
# INFO:root:Extracted 1480000 concept assertions
# INFO:root:Extracted 1490000 concept assertions
# INFO:root:Extracted 1500000 concept assertions
# INFO:root:Extracted 1510000 concept assertions
# INFO:root:Extracted 1520000 concept assertions
# INFO:root:Extracted 1530000 concept assertions
# INFO:root:Extracted 1540000 concept assertions
# INFO:root:Extracted 1550000 concept assertions
# INFO:root:Extracted 1560000 concept assertions
# INFO:root:Extracted 1570000 concept assertions
# INFO:root:Extracted 1580000 concept assertions
# INFO:root:Extracted 1590000 concept assertions
# INFO:root:Extracted 1600000 concept assertions
# INFO:root:Extracted 1610000 concept assertions
# INFO:root:Extracted 1620000 concept assertions
# INFO:root:Extracted 1630000 concept assertions
# INFO:root:Extracted 1640000 concept assertions
# INFO:root:Extracted 1650000 concept assertions
# INFO:root:Extracted 1660000 concept assertions
# INFO:root:Extracted 1670000 concept assertions
# INFO:root:Extracted 1680000 concept assertions
# INFO:root:Extracted 1690000 concept assertions
# INFO:root:Extracted 1700000 concept assertions
# INFO:root:Extracted 1710000 concept assertions
# INFO:root:Extracted 1720000 concept assertions
# INFO:root:Extracted 1730000 concept assertions
# INFO:root:Extracted 1740000 concept assertions
# INFO:root:Extracted 1750000 concept assertions
# INFO:root:Extracted 1760000 concept assertions
# INFO:root:Extracted 1770000 concept assertions
# INFO:root:Extracted 1780000 concept assertions
# INFO:root:Extracted 1790000 concept assertions
# INFO:root:Extracted 1800000 concept assertions
# INFO:root:Extracted 1810000 concept assertions
# INFO:root:Extracted 1820000 concept assertions
# INFO:root:Extracted 1830000 concept assertions
# INFO:root:Extracted 1840000 concept assertions
# INFO:root:Extracted 1850000 concept assertions
# INFO:root:Extracted 1860000 concept assertions
# INFO:root:Extracted 1870000 concept assertions
# INFO:root:Extracted 1880000 concept assertions
# INFO:root:Extracted 1890000 concept assertions
# INFO:root:Extracted 1900000 concept assertions
# INFO:root:Extracted 1910000 concept assertions
# INFO:root:Extracted 1920000 concept assertions
# INFO:root:Extracted 1930000 concept assertions
# INFO:root:Extracted 1940000 concept assertions
# INFO:root:Extracted 1950000 concept assertions
# INFO:root:Extracted 1960000 concept assertions
# INFO:root:Extracted 1970000 concept assertions
# INFO:root:Extracted 1980000 concept assertions
# INFO:root:Extracted 1990000 concept assertions
# INFO:root:Extracted 2000000 concept assertions
# INFO:root:Extracted 2010000 concept assertions
# INFO:root:Extracted 2020000 concept assertions
# INFO:root:Extracted 2030000 concept assertions
# INFO:root:Extracted 2040000 concept assertions
# INFO:root:Extracted 2050000 concept assertions
# INFO:root:Extracted 2060000 concept assertions
# INFO:root:Extracted 2070000 concept assertions
# INFO:root:Extracted 2080000 concept assertions
# INFO:root:Extracted 2090000 concept assertions
# INFO:root:Extracted 2100000 concept assertions
# INFO:root:Extracted 2110000 concept assertions
# INFO:root:Extracted 2120000 concept assertions
# INFO:root:Extracted 2830000 concept assertions
# INFO:root:Extracted 2840000 concept assertions
# INFO:root:Extracted 2850000 concept assertions
# INFO:root:Extracted 2860000 concept assertions
# INFO:root:Extracted 2870000 concept assertions
# INFO:root:Extracted 2880000 concept assertions
# INFO:root:Extracted 2890000 concept assertions
# INFO:root:Extracted 2900000 concept assertions
# INFO:root:Extracted 2910000 concept assertions
# INFO:root:Extracted 2920000 concept assertions
# INFO:root:Extracted 2930000 concept assertions
# INFO:root:Extracted 2940000 concept assertions
# INFO:root:Extracted 2950000 concept assertions
# INFO:root:Extracted 2960000 concept assertions
# INFO:root:Extracted 2970000 concept assertions
# INFO:root:Extracted 2980000 concept assertions
# INFO:root:Extracted 2990000 concept assertions
# INFO:root:Extracted 3000000 concept assertions
# INFO:root:Extracted 3010000 concept assertions
# INFO:root:Extracted 3020000 concept assertions
# INFO:root:Extracted 3030000 concept assertions
# INFO:root:Extracted 3040000 concept assertions
# INFO:root:Extracted 3050000 concept assertions
# INFO:root:Extracted 3060000 concept assertions
# INFO:root:Extracted 3070000 concept assertions
# INFO:root:Extracted 3080000 concept assertions
# INFO:root:Extracted 3090000 concept assertions
# INFO:root:Extracted 3100000 concept assertions
# INFO:root:Extracted 3110000 concept assertions
# INFO:root:Extracted 3120000 concept assertions
# INFO:root:Extracted 3130000 concept assertions
# INFO:root:Extracted 3140000 concept assertions
# INFO:root:Extracted 3150000 concept assertions
# INFO:root:Extracted 3160000 concept assertions
# INFO:root:Extracted 3170000 concept assertions
# INFO:root:Extracted 3180000 concept assertions
# INFO:root:Extracted 3190000 concept assertions
# INFO:root:Extracted 3200000 concept assertions
# INFO:root:Extracted 3210000 concept assertions
# INFO:root:Extracted 3220000 concept assertions
# INFO:root:Extracted 3230000 concept assertions
# INFO:root:Extracted 3240000 concept assertions
# INFO:root:Extracted 3250000 concept assertions
# INFO:root:Extracted 3260000 concept assertions
# INFO:root:Extracted 3270000 concept assertions
# INFO:root:Extracted 3280000 concept assertions
# INFO:root:Extracted 3290000 concept assertions
# INFO:root:Extracted 3300000 concept assertions
# INFO:root:Extracted 3310000 concept assertions
# INFO:root:Extracted 3320000 concept assertions
# INFO:root:Extracted 3330000 concept assertions
# INFO:root:Extracted 3340000 concept assertions
# INFO:root:Extracted 3350000 concept assertions
# INFO:root:Extracted 3360000 concept assertions
# INFO:root:Extracted 3370000 concept assertions
# INFO:root:Extracted 3380000 concept assertions
# INFO:root:Extracted 3390000 concept assertions
# INFO:root:Extracted 3400000 concept assertions
# INFO:root:Extracted 3410000 concept assertions
# INFO:root:Extracted 3420000 concept assertions
# INFO:root:Extracted 3430000 concept assertions
# INFO:root:Extracted 3440000 concept assertions
# INFO:root:Extracted 3450000 concept assertions
# INFO:root:Extracted 3460000 concept assertions
# INFO:root:Extracted 3470000 concept assertions
# INFO:root:Extracted 3480000 concept assertions
# INFO:root:Extracted 3490000 concept assertions
# INFO:root:Extracted 3500000 concept assertions
# INFO:root:Extracted 3510000 concept assertions
# INFO:root:Extracted 3520000 concept assertions
# INFO:root:Extracted 3530000 concept assertions
# INFO:root:Extracted 7070000 concept assertions
# INFO:root:Extracted 7080000 concept assertions
# INFO:root:Extracted 7090000 concept assertions
# INFO:root:Extracted 7100000 concept assertions
# INFO:root:Extracted 7110000 concept assertions
# INFO:root:Extracted 7120000 concept assertions
# INFO:root:Extracted 7130000 concept assertions
# INFO:root:Extracted 7140000 concept assertions
# INFO:root:Extracted 7150000 concept assertions
# INFO:root:Extracted 7160000 concept assertions
# INFO:root:Extracted 7170000 concept assertions
# INFO:root:Extracted 7180000 concept assertions
# INFO:root:Extracted 7190000 concept assertions
# INFO:root:Extracted 7200000 concept assertions
# INFO:root:Extracted 7210000 concept assertions
# INFO:root:Extracted 7220000 concept assertions
# INFO:root:Extracted 7230000 concept assertions
# INFO:root:Extracted 7240000 concept assertions
# INFO:root:Extracted 7250000 concept assertions
# INFO:root:Extracted 7260000 concept assertions
# INFO:root:Extracted 7270000 concept assertions
# INFO:root:Extracted 7280000 concept assertions
# INFO:root:Extracted 7290000 concept assertions
# INFO:root:Extracted 7300000 concept assertions
# INFO:root:Extracted 7310000 concept assertions
# INFO:root:Extracted 7320000 concept assertions
# INFO:root:Extracted 7330000 concept assertions
# INFO:root:Extracted 7340000 concept assertions
# INFO:root:Extracted 7350000 concept assertions
# INFO:root:Extracted 7360000 concept assertions
# INFO:root:Extracted 7370000 concept assertions
# INFO:root:Extracted 7380000 concept assertions
# INFO:root:Extracted 7390000 concept assertions
# INFO:root:Extracted 7400000 concept assertions
# INFO:root:Extracted 7410000 concept assertions
# INFO:root:Extracted 7420000 concept assertions
# INFO:root:Extracted 7430000 concept assertions
# INFO:root:Extracted 7440000 concept assertions
# INFO:root:Extracted 7450000 concept assertions
# INFO:root:Extracted 7460000 concept assertions
# INFO:root:Extracted 7470000 concept assertions
# INFO:root:Extracted 7480000 concept assertions
# INFO:root:Extracted 7490000 concept assertions
# INFO:root:Extracted 7500000 concept assertions
# INFO:root:Extracted 7510000 concept assertions
# INFO:root:Extracted 7520000 concept assertions
# INFO:root:Extracted 7530000 concept assertions
# INFO:root:Extracted 7540000 concept assertions
# INFO:root:Extracted 7550000 concept assertions
# INFO:root:Extracted 7560000 concept assertions
# INFO:root:Extracted 7570000 concept assertions
# INFO:root:Extracted 7580000 concept assertions
# INFO:root:Extracted 7590000 concept assertions
# INFO:root:Extracted 7600000 concept assertions
# INFO:root:Extracted 7610000 concept assertions
# INFO:root:Extracted 7620000 concept assertions
# INFO:root:Extracted 7630000 concept assertions
# INFO:root:Extracted 7640000 concept assertions
# INFO:root:Extracted 7650000 concept assertions
# INFO:root:Extracted 7660000 concept assertions
# INFO:root:Extracted 7670000 concept assertions
# INFO:root:Extracted 7680000 concept assertions
# INFO:root:Extracted 7690000 concept assertions
# INFO:root:Extracted 7700000 concept assertions
# INFO:root:Extracted 7710000 concept assertions
# INFO:root:Extracted 7720000 concept assertions
# INFO:root:Extracted 7730000 concept assertions
# INFO:root:Extracted 7740000 concept assertions
# INFO:root:Extracted 7750000 concept assertions
# INFO:root:Extracted 7760000 concept assertions
# INFO:root:Extracted 7770000 concept assertions
# INFO:root:Extracted 7780000 concept assertions
# INFO:root:Extracted 7790000 concept assertions
# INFO:root:Extracted 7800000 concept assertions
# INFO:root:Extracted 7810000 concept assertions
# INFO:root:Extracted 7820000 concept assertions
# INFO:root:Extracted 7830000 concept assertions
# INFO:root:Extracted 7840000 concept assertions
# INFO:root:Extracted 7850000 concept assertions
# INFO:root:Extracted 7860000 concept assertions
# INFO:root:Extracted 7870000 concept assertions
# INFO:root:Extracted 7880000 concept assertions
# INFO:root:Extracted 7890000 concept assertions
# INFO:root:Extracted 7900000 concept assertions
# INFO:root:Extracted 7910000 concept assertions
# INFO:root:Extracted 7920000 concept assertions
# INFO:root:Extracted 7930000 concept assertions
# INFO:root:Extracted 7940000 concept assertions
# INFO:root:Extracted 7950000 concept assertions
# INFO:root:Extracted 7960000 concept assertions
# INFO:root:Extracted 7970000 concept assertions
# INFO:root:Extracted 7980000 concept assertions
# INFO:root:Extracted 7990000 concept assertions
# INFO:root:Extracted 8000000 concept assertions
# INFO:root:Extracted 8010000 concept assertions
# INFO:root:Extracted 8020000 concept assertions
# INFO:root:Extracted 8030000 concept assertions
# INFO:root:Extracted 8040000 concept assertions
# INFO:root:Extracted 8050000 concept assertions
# INFO:root:Extracted 8060000 concept assertions
# INFO:root:Extracted 8070000 concept assertions
# INFO:root:Extracted 8080000 concept assertions
# INFO:root:Extracted 8090000 concept assertions
# INFO:root:Extracted 8100000 concept assertions
# INFO:root:Extracted 8110000 concept assertions
# INFO:root:Extracted 8120000 concept assertions
# INFO:root:Extracted 8130000 concept assertions
# INFO:root:Extracted 8140000 concept assertions
# INFO:root:Extracted 8150000 concept assertions
# INFO:root:Extracted 8160000 concept assertions
# INFO:root:Extracted 8170000 concept assertions
# INFO:root:Extracted 8180000 concept assertions
# INFO:root:Extracted 8190000 concept assertions
# INFO:root:Extracted 8200000 concept assertions
# INFO:root:Extracted 8210000 concept assertions
# INFO:root:Extracted 8220000 concept assertions
# INFO:root:Extracted 8230000 concept assertions
# INFO:root:Extracted 8240000 concept assertions
# INFO:root:Extracted 8250000 concept assertions
# INFO:root:Extracted 8260000 concept assertions
# INFO:root:Extracted 8270000 concept assertions
# INFO:root:Extracted 8280000 concept assertions
# INFO:root:Extracted 8290000 concept assertions
# INFO:root:Extracted 8300000 concept assertions
# INFO:root:Extracted 8310000 concept assertions
# INFO:root:Extracted 8320000 concept assertions
# INFO:root:Extracted 8330000 concept assertions
# INFO:root:Extracted 8340000 concept assertions
# INFO:root:Extracted 8350000 concept assertions
# INFO:root:Extracted 8360000 concept assertions
# INFO:root:Extracted 8370000 concept assertions
# INFO:root:Extracted 8380000 concept assertions
# INFO:root:Extracted 8390000 concept assertions
# INFO:root:Extracted 8400000 concept assertions
# INFO:root:Extracted 8410000 concept assertions
# INFO:root:Extracted 8420000 concept assertions
# INFO:root:Extracted 8430000 concept assertions
# INFO:root:Extracted 8440000 concept assertions
# INFO:root:Extracted 8450000 concept assertions
# INFO:root:Extracted 8460000 concept assertions
# INFO:root:Extracted 8470000 concept assertions
# INFO:root:Extracted 8480000 concept assertions
# INFO:root:Extracted 8490000 concept assertions
# INFO:root:Extracted 8500000 concept assertions
# INFO:root:Extracted 8510000 concept assertions
# INFO:root:Extracted 8520000 concept assertions
# INFO:root:Extracted 8530000 concept assertions
# INFO:root:Extracted 8540000 concept assertions
# INFO:root:Extracted 8550000 concept assertions
# INFO:root:Extracted 8560000 concept assertions
# INFO:root:Extracted 8570000 concept assertions
# INFO:root:Extracted 8580000 concept assertions
# INFO:root:Extracted 8590000 concept assertions
# INFO:root:Extracted 8600000 concept assertions
# INFO:root:Extracted 8610000 concept assertions
# INFO:root:Extracted 8620000 concept assertions
# INFO:root:Extracted 8630000 concept assertions
# INFO:root:Extracted 8640000 concept assertions
# INFO:root:Extracted 8650000 concept assertions
# INFO:root:Extracted 8660000 concept assertions
# INFO:root:Extracted 8670000 concept assertions
# INFO:root:Extracted 8680000 concept assertions
# INFO:root:Extracted 8690000 concept assertions
# INFO:root:Extracted 8700000 concept assertions
# INFO:root:Extracted 8710000 concept assertions
# INFO:root:Extracted 8720000 concept assertions
# INFO:root:Extracted 8730000 concept assertions
# INFO:root:Extracted 8740000 concept assertions
# INFO:root:Extracted 8750000 concept assertions
# INFO:root:Extracted 8760000 concept assertions
# INFO:root:Extracted 8770000 concept assertions
# INFO:root:Extracted 8780000 concept assertions
# INFO:root:Extracted 8790000 concept assertions
# INFO:root:Extracted 8800000 concept assertions
# INFO:root:Extracted 8810000 concept assertions
# INFO:root:Extracted 8820000 concept assertions
# INFO:root:Extracted 8830000 concept assertions
# INFO:root:Extracted 8840000 concept assertions
# INFO:root:Extracted 8850000 concept assertions
# INFO:root:Extracted 8860000 concept assertions
# INFO:root:Extracted 8870000 concept assertions
# INFO:root:Extracted 8880000 concept assertions
# INFO:root:Extracted 8890000 concept assertions
# INFO:root:Extracted 8900000 concept assertions
# INFO:root:Extracted 8910000 concept assertions
# INFO:root:Extracted 8920000 concept assertions
# INFO:root:Extracted 8930000 concept assertions
# INFO:root:Extracted 8940000 concept assertions
# INFO:root:Extracted 8950000 concept assertions
# INFO:root:Extracted 8960000 concept assertions
# INFO:root:Extracted 8970000 concept assertions
# INFO:root:Extracted 8980000 concept assertions
# INFO:root:Extracted 8990000 concept assertions
# INFO:root:Extracted 9000000 concept assertions
# INFO:root:Extracted 9010000 concept assertions
# INFO:root:Extracted 9020000 concept assertions
# INFO:root:Extracted 9030000 concept assertions
# INFO:root:Extracted 9040000 concept assertions
# INFO:root:Extracted 9050000 concept assertions
# INFO:root:Extracted 9060000 concept assertions
# INFO:root:Extracted 9070000 concept assertions
# INFO:root:Extracted 9080000 concept assertions
# INFO:root:Extracted 9090000 concept assertions
# INFO:root:Extracted 9100000 concept assertions
# INFO:root:Extracted 9110000 concept assertions
# INFO:root:Extracted 9120000 concept assertions
# INFO:root:Extracted 9130000 concept assertions
# INFO:root:Extracted 9140000 concept assertions
# INFO:root:Extracted 9150000 concept assertions
# INFO:root:Extracted 9160000 concept assertions
# INFO:root:Extracted 9170000 concept assertions
# INFO:root:Extracted 29960000 concept assertions
# INFO:root:Extracted 29970000 concept assertions
# INFO:root:Extracted 29980000 concept assertions
# INFO:root:Extracted 29990000 concept assertions
# INFO:root:Extracted 30000000 concept assertions
# INFO:root:Extracted 30010000 concept assertions
# INFO:root:Extracted 30020000 concept assertions
# INFO:root:Extracted 30030000 concept assertions
# INFO:root:Extracted 30040000 concept assertions
# INFO:root:Extracted 30050000 concept assertions
# INFO:root:Extracted 30060000 concept assertions
# INFO:root:Extracted 30070000 concept assertions
# INFO:root:Extracted 30080000 concept assertions
# INFO:root:Extracted 30090000 concept assertions
# INFO:root:Extracted 30100000 concept assertions
# INFO:root:Extracted 30110000 concept assertions
# INFO:root:Extracted 30120000 concept assertions
# INFO:root:Extracted 30130000 concept assertions
# INFO:root:Extracted 30140000 concept assertions
# INFO:root:Extracted 30150000 concept assertions
# INFO:root:Extracted 30160000 concept assertions
# INFO:root:Extracted 30170000 concept assertions
# INFO:root:Extracted 30180000 concept assertions
# INFO:root:Extracted 30190000 concept assertions
# INFO:root:Extracted 30200000 concept assertions
# INFO:root:Extracted 30210000 concept assertions
# INFO:root:Extracted 30220000 concept assertions
# INFO:root:Extracted 30230000 concept assertions
# INFO:root:Extracted 30240000 concept assertions
# INFO:root:Extracted 30250000 concept assertions
# INFO:root:Extracted 30260000 concept assertions
# INFO:root:Extracted 30270000 concept assertions
# INFO:root:Extracted 30280000 concept assertions
# INFO:root:Extracted 30290000 concept assertions
# INFO:root:Extracted 30300000 concept assertions
# INFO:root:Extracted 30310000 concept assertions
# INFO:root:Extracted 30320000 concept assertions
# INFO:root:Extracted 30330000 concept assertions
# INFO:root:Extracted 30340000 concept assertions
# INFO:root:Extracted 30350000 concept assertions
# INFO:root:Extracted 30360000 concept assertions
# INFO:root:Extracted 30370000 concept assertions
# INFO:root:Extracted 30380000 concept assertions
# INFO:root:Extracted 30390000 concept assertions
# INFO:root:Extracted 30400000 concept assertions
# INFO:root:Extracted 30410000 concept assertions
# INFO:root:Extracted 30420000 concept assertions
# INFO:root:Extracted 30430000 concept assertions
# INFO:root:Extracted 30440000 concept assertions
# INFO:root:Extracted 30450000 concept assertions
# INFO:root:Extracted 30460000 concept assertions
# INFO:root:Extracted 30470000 concept assertions
# INFO:root:Extracted 30480000 concept assertions
# INFO:root:Extracted 30490000 concept assertions
# INFO:root:Extracted 30500000 concept assertions
# INFO:root:Extracted 30510000 concept assertions
# INFO:root:Extracted 30520000 concept assertions
# INFO:root:Extracted 30530000 concept assertions
# INFO:root:Extracted 30540000 concept assertions
# INFO:root:Extracted 30550000 concept assertions
# INFO:root:Extracted 30560000 concept assertions
# INFO:root:Extracted 30570000 concept assertions
# INFO:root:Extracted 30580000 concept assertions
# INFO:root:Extracted 30590000 concept assertions
# INFO:root:Extracted 30600000 concept assertions
# INFO:root:Extracted 30610000 concept assertions
# INFO:root:Extracted 30620000 concept assertions
# INFO:root:Extracted 30630000 concept assertions
# INFO:root:Extracted 30640000 concept assertions
# INFO:root:Extracted 30650000 concept assertions
# INFO:root:Extracted 30660000 concept assertions
# INFO:root:Extracted 30670000 concept assertions
# INFO:root:Extracted 30680000 concept assertions
# INFO:root:Extracted 30690000 concept assertions
# INFO:root:Extracted 30700000 concept assertions
# INFO:root:Extracted 30710000 concept assertions
# INFO:root:Extracted 30720000 concept assertions
# INFO:root:Extracted 30730000 concept assertions
# INFO:root:Extracted 30740000 concept assertions
# INFO:root:Extracted 30750000 concept assertions
# INFO:root:Extracted 30760000 concept assertions
# INFO:root:Extracted 30770000 concept assertions
# INFO:root:Extracted 30780000 concept assertions
# INFO:root:Extracted 30790000 concept assertions
# INFO:root:Extracted 30800000 concept assertions
# INFO:root:Extracted 30810000 concept assertions
# INFO:root:Extracted 30820000 concept assertions
# INFO:root:Extracted 30830000 concept assertions
# INFO:root:Extracted 30840000 concept assertions
# INFO:root:Extracted 30850000 concept assertions
# INFO:root:Extracted 30860000 concept assertions
# INFO:root:Extracted 30870000 concept assertions
# INFO:root:Extracted 30880000 concept assertions
# INFO:root:Extracted 30890000 concept assertions
# INFO:root:Extracted 30900000 concept assertions
# INFO:root:Extracted 30910000 concept assertions
# INFO:root:Extracted 30920000 concept assertions
# INFO:root:Extracted 30930000 concept assertions
# INFO:root:Extracted 30940000 concept assertions
# INFO:root:Extracted 30950000 concept assertions
# INFO:root:Extracted 30960000 concept assertions
# INFO:root:Extracted 30970000 concept assertions
# INFO:root:Extracted 30980000 concept assertions
# INFO:root:Extracted 30990000 concept assertions
# INFO:root:Extracted 31000000 concept assertions
# INFO:root:Extracted 31010000 concept assertions
# INFO:root:Extracted 31020000 concept assertions
# INFO:root:Extracted 31030000 concept assertions
# INFO:root:Extracted 31040000 concept assertions
# INFO:root:Extracted 31050000 concept assertions
# INFO:root:Extracted 31060000 concept assertions
# INFO:root:Extracted 31070000 concept assertions
# INFO:root:Extracted 31080000 concept assertions
# INFO:root:Extracted 31090000 concept assertions
# INFO:root:Extracted 31100000 concept assertions
# INFO:root:Extracted 31110000 concept assertions
# INFO:root:Extracted 31120000 concept assertions
# INFO:root:Extracted 31130000 concept assertions
# INFO:root:Extracted 31140000 concept assertions
# INFO:root:Extracted 31150000 concept assertions
# INFO:root:Extracted 31160000 concept assertions
# INFO:root:Extracted 31170000 concept assertions
# INFO:root:Extracted 31180000 concept assertions
# INFO:root:Extracted 31190000 concept assertions
# INFO:root:Extracted 31200000 concept assertions
# INFO:root:Extracted 31210000 concept assertions
# INFO:root:Extracted 31220000 concept assertions
# INFO:root:Extracted 31230000 concept assertions
# INFO:root:Extracted 31240000 concept assertions
# INFO:root:Extracted 31250000 concept assertions
# INFO:root:Extracted 31260000 concept assertions
# INFO:root:Extracted 31270000 concept assertions
# INFO:root:Extracted 31280000 concept assertions
# INFO:root:Extracted 31290000 concept assertions
# INFO:root:Extracted 31300000 concept assertions
# INFO:root:Extracted 31310000 concept assertions
# INFO:root:Extracted 31320000 concept assertions
# INFO:root:Extracted 31330000 concept assertions
# INFO:root:Extracted 31340000 concept assertions
# INFO:root:Extracted 31350000 concept assertions
# INFO:root:Extracted 31360000 concept assertions
# INFO:root:Extracted 31370000 concept assertions
# INFO:root:Extracted 31380000 concept assertions
# INFO:root:Extracted 31390000 concept assertions
# INFO:root:Extracted 31400000 concept assertions
# INFO:root:Extracted 31410000 concept assertions
# INFO:root:Extracted 31420000 concept assertions
# INFO:root:Extracted 31430000 concept assertions
# INFO:root:Extracted 31440000 concept assertions
# INFO:root:Extracted 31450000 concept assertions
# INFO:root:Extracted 31460000 concept assertions
# INFO:root:Extracted 31470000 concept assertions
# INFO:root:Extracted 31480000 concept assertions
# INFO:root:Extracted 31490000 concept assertions
# INFO:root:Extracted 31500000 concept assertions
# INFO:root:Extracted 31510000 concept assertions
# INFO:root:Extracted 31520000 concept assertions
# INFO:root:Extracted 31530000 concept assertions
# INFO:root:Extracted 31540000 concept assertions
# INFO:root:Extracted 31550000 concept assertions
# INFO:root:Extracted 31560000 concept assertions
# INFO:root:Extracted 31570000 concept assertions
# INFO:root:Extracted 31580000 concept assertions
# INFO:root:Extracted 31590000 concept assertions
# INFO:root:Extracted 31600000 concept assertions
# INFO:root:Extracted 31610000 concept assertions
# INFO:root:Extracted 31620000 concept assertions
# INFO:root:Extracted 31630000 concept assertions
# INFO:root:Extracted 31640000 concept assertions
# INFO:root:Extracted 31650000 concept assertions
# INFO:root:Extracted 31660000 concept assertions
# INFO:root:Extracted 31670000 concept assertions
# INFO:root:Extracted 31680000 concept assertions
# INFO:root:Extracted 31690000 concept assertions
# INFO:root:Extracted 31700000 concept assertions
# INFO:root:Extracted 31710000 concept assertions
# INFO:root:Extracted 31720000 concept assertions
# INFO:root:Extracted 31730000 concept assertions
# INFO:root:Extracted 31740000 concept assertions
# INFO:root:Extracted 31750000 concept assertions
# INFO:root:Extracted 31760000 concept assertions
# INFO:root:Extracted 31770000 concept assertions
# INFO:root:Extracted 31780000 concept assertions
# INFO:root:Extracted 31790000 concept assertions
# INFO:root:Extracted 31800000 concept assertions
# INFO:root:Extracted 31810000 concept assertions
# INFO:root:Extracted 31820000 concept assertions
# INFO:root:Extracted 31830000 concept assertions
# INFO:root:Extracted 31840000 concept assertions
# INFO:root:Extracted 31850000 concept assertions
# INFO:root:Extracted 31860000 concept assertions
# INFO:root:Extracted 31870000 concept assertions
# INFO:root:Extracted 31880000 concept assertions
# INFO:root:Extracted 31890000 concept assertions
# INFO:root:Extracted 31900000 concept assertions
# INFO:root:Extracted 31910000 concept assertions
# INFO:root:Extracted 31920000 concept assertions
# INFO:root:Extracted 31930000 concept assertions
# INFO:root:Extracted 31940000 concept assertions
# INFO:root:Extracted 31950000 concept assertions
# INFO:root:Extracted 31960000 concept assertions
# INFO:root:Extracted 31970000 concept assertions
# INFO:root:Extracted 31980000 concept assertions
# INFO:root:Extracted 31990000 concept assertions
# INFO:root:Extracted 32000000 concept assertions
# INFO:root:Extracted 32010000 concept assertions
# INFO:root:Extracted 32020000 concept assertions
# INFO:root:Extracted 32030000 concept assertions
# INFO:root:Extracted 32040000 concept assertions
# INFO:root:Extracted 32050000 concept assertions
# INFO:root:Extracted 32060000 concept assertions
# INFO:root:Extracted 32070000 concept assertions
# INFO:root:Extracted 32080000 concept assertions
# INFO:root:Extracted 32090000 concept assertions
# INFO:root:Extracted 32100000 concept assertions
# INFO:root:Extracted 32110000 concept assertions
# INFO:root:Extracted 32120000 concept assertions
# INFO:root:Extracted 32130000 concept assertions
# INFO:root:Extracted 32140000 concept assertions
# INFO:root:Extracted 32150000 concept assertions
# INFO:root:Extracted 32160000 concept assertions
# INFO:root:Extracted 32170000 concept assertions
# INFO:root:Extracted 32180000 concept assertions
# INFO:root:Extracted 32190000 concept assertions
# INFO:root:Extracted 32200000 concept assertions
# INFO:root:Extracted 32210000 concept assertions
# INFO:root:Extracted 32220000 concept assertions
# INFO:root:Extracted 32230000 concept assertions
# INFO:root:Extracted 32240000 concept assertions
# INFO:root:Extracted 32250000 concept assertions
# INFO:root:Extracted 32260000 concept assertions
# INFO:root:Extracted 32270000 concept assertions
# INFO:root:Extracted 32280000 concept assertions
# INFO:root:Extracted 32290000 concept assertions
# INFO:root:Extracted 32300000 concept assertions
# INFO:root:Extracted 32310000 concept assertions
# INFO:root:Extracted 32320000 concept assertions
# INFO:root:Extracted 32330000 concept assertions
# INFO:root:Extracted 32340000 concept assertions
# INFO:root:Extracted 32350000 concept assertions
# INFO:root:Extracted 32360000 concept assertions
# INFO:root:Extracted 32370000 concept assertions
# INFO:root:Extracted 32380000 concept assertions
# INFO:root:Extracted 32390000 concept assertions
# INFO:root:Extracted 32400000 concept assertions
# INFO:root:Extracted 32410000 concept assertions
# INFO:root:Extracted 32420000 concept assertions
# INFO:root:Extracted 32430000 concept assertions
# INFO:root:Extracted 32440000 concept assertions
# INFO:root:Extracted 32450000 concept assertions
# INFO:root:Extracted 32460000 concept assertions
# INFO:root:Extracted 32470000 concept assertions
# INFO:root:Extracted 32480000 concept assertions
# INFO:root:Extracted 32490000 concept assertions
# INFO:root:Extracted 32500000 concept assertions
# INFO:root:Extracted 32510000 concept assertions
# INFO:root:Extracted 32520000 concept assertions
# INFO:root:Extracted 32530000 concept assertions
# INFO:root:Extracted 32540000 concept assertions
# INFO:root:Extracted 32550000 concept assertions
# INFO:root:Extracted 32560000 concept assertions
# INFO:root:Extracted 32570000 concept assertions
# INFO:root:Extracted 32580000 concept assertions
# INFO:root:Extracted 32590000 concept assertions
# INFO:root:Extracted 32600000 concept assertions
# INFO:root:Extracted 32610000 concept assertions
# INFO:root:Extracted 32620000 concept assertions
# INFO:root:Extracted 32630000 concept assertions
# INFO:root:Extracted 32640000 concept assertions
# INFO:root:Extracted 32650000 concept assertions
# INFO:root:Extracted 32660000 concept assertions
# INFO:root:Extracted 32670000 concept assertions
# INFO:root:Extracted 32680000 concept assertions
# INFO:root:Extracted 32690000 concept assertions
# INFO:root:Extracted 32700000 concept assertions
# INFO:root:Extracted 32710000 concept assertions
# INFO:root:Extracted 32720000 concept assertions
# INFO:root:Extracted 32730000 concept assertions
# INFO:root:Extracted 32740000 concept assertions
# INFO:root:Extracted 32750000 concept assertions
# INFO:root:Writing synsets
# INFO:root:Writing Relationships
# INFO:root:Writing Words
